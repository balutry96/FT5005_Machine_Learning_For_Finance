# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoModel, AutoTokenizer
from transformers import pipeline, AutoModelForSequenceClassification
from sklearn.cluster import KMeans
import torch.nn.functional as F
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Bidirectional, BatchNormalization

# %%
# Download stopwords list
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/balubabu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/balubabu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stock_tweets = pd.read_csv('stock_tweets.csv')
stock_data = pd.read_csv('stock_yfinance_data.csv')

# %%
print(stock_tweets.columns)
print(stock_data.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Date', 'Tweet', 'Stock Name',
#        'Company Name', 'Cluster', 'Sentiment_Score'],
#       dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Stock Name'],
#       dtype='object')

# %%
print("Dimensions of the stock_tweets: ", stock_tweets.shape)
print("Dimensions of the stock data: ", stock_data.shape)
# Out:
# Dimensions of the stock_tweets:  (9145, 8)
# Dimensions of the stock data:  (3024, 8)

# %% [markdown]
# ### Q1 (3 marks) BERT and Clustering!

# %%
def preprocess_text(text):
    # Convert to lower case
    text = text.lower()
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove user @ references and '#' from tweet
    text = re.sub(r'\@\w+|\#','', text)
    # Remove punctuations
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    word_tokens = nltk.word_tokenize(text)
    filtered_text = [word for word in word_tokens if word not in stop_words]
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_output = [lemmatizer.lemmatize(word) for word in filtered_text]
    # Re-create document from filtered tokens
    text = ' '.join(lemmatized_output)
    return text
stock_tweets['Tweet'] = [preprocess_text(tweet) for tweet in stock_tweets['Tweet']]

# %%
# Load tokenizer and model from Hugging Face Hub
model_name = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, output_hidden_states=True)

# Create a sentiment analysis pipeline using the loaded model and tokenizer
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

tweets = stock_tweets['Tweet']

# Analyze the sentiment of each tweet
results = [(tweet, sentiment_pipeline(tweet)) for tweet in tweets]

# Print the results
for tweet, sentiment in results:
    print(f"Tweet: {tweet}\nSentiment: {sentiment}\n")
    
# Function to convert tweets to embeddings
def get_embeddings(tweets, tokenizer, model):
    embeddings = []
    max_len = 0
    for tweet in tweets:
        # Encode the tweets
        encoded_input = tokenizer(tweet, return_tensors='pt', padding=True, truncation=True, max_length=512)
        # Generate embeddings
        with torch.no_grad():
            outputs = model(**encoded_input)
        # Retrieve the full hidden states for the last layer
        tweet_embeddings = outputs.hidden_states[-1]
        max_len = max(max_len, tweet_embeddings.size(1))
        embeddings.append(tweet_embeddings)
        
    # Pad embeddings to the maximum length
    padded_embeddings = [F.pad(embed, (0, 0, 0, max_len - embed.size(1))) for embed in embeddings]
    # Concatenate along the batch dimension
    final_embeddings = torch.cat(padded_embeddings, dim=0)
    
    return final_embeddings.cpu().numpy()
    
# Obtain embeddings
embeddings = get_embeddings(tweets, tokenizer, model)

# Example of how to handle one of the embeddings
# Let's print the dimensions and some part of the embedding of the first tweet to confirm
print("Embedding dimensions for the first tweet:", embeddings[0].shape) # dimension is 768
# Out:
# Tweet: bought first aapl stock since seen increase tell dont invest
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6648916006088257}]
#
# Tweet: medium really pushing hard big money client tsla option tomorrow sht make laughable even hitting new low anyone care sell stock year ago buffett sold aapl last year talk
# Sentiment: [{'label': 'LABEL_1', 'score': 0.508172333240509}]
#
# Tweet: tim cook ceo aapl earned total compensation warren buffett earned dividend aapl zero hour clocked zero meeting amp zero headache caused invest
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5247932076454163}]
#
# Tweet: thread broad overview balance sheet want specific amp helpful example deep dive balance sheet youtube channel using aapls recent number example
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7013223171234131}]
#
# Tweet: trendline aapl continuing reject
# Sentiment: [{'label': 'LABEL_0', 'score': 0.626981794834137}]
#
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx amazon amzn apple aapl sampp spy bond agg gold gld literally picked worst performing asset
# Sentiment: [{'label': 'LABEL_0', 'score': 0.7542157769203186}]
#
# Tweet: need share aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.818841814994812}]
#
# Tweet: trade plan friday spx fails p work spx hold open c work lotto amzn pull back tomorrow put work aapl hold bounce mon call work
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5190474987030029}]
#
# Tweet: disclaimer high risk lottofriday keep bet small lock gain aapl c gt p lt afrm c gt p lt chwy c gt p lt mrna c gt p lt good luck
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6310213804244995}]
#
# Tweet: eod leaderboard amc c qqq p uvxy c amc c ung c aapl p mrk c teva c full list
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8852108120918274}]
#
# Tweet: september vol vix tesla tsla bond agg gold gld sampp spy amazon amzn na qqq apple aapl microsoft msft googl bitcoin btc ark innovation arkk facebook fb ethereum eth evergrande egrnf
# Sentiment: [{'label': 'LABEL_1', 'score': 0.866442084312439}]
#
# Tweet: aapl monthly bearish engulfing nearing prior supply zone
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6091129183769226}]
#
# Tweet: share aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8116019368171692}]
#
# Tweet: talking aapl customer service morning asked model iphone paused good second think thats cycle
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5568401217460632}]
#
# Tweet: tech focused firm dominate top market cap tech company think make list aapl msft googl amzn fb tsla tsm tcehy
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6524484157562256}]
#
# Tweet: aapl mentioned ticker wsb
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8400372862815857}]
#
# Tweet: signing weekend friendly reminder q went long cmg ran amzn ran aapl august c shop ran nke august call ran nflx october call ran free amp join u q lfg
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9157531261444092}]
#
# Tweet: result lottofriday aapl p afrm p chwy p mrna p mrna gapped gave u retest move cheer hagw
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8737623691558838}]
#
# Tweet: woah aapl currently bullish darkpool playing link
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7651563286781311}]
#
# Tweet: portfolio holding year tla tesla pltr palantir voo btc bitcoin b se sea ltd nvda nvidia vti eth ethereum c goog google upst upstart arkk doge dogecoin aapl apple sofi sofi qqq ada cardano
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8914335370063782}]
#
# Tweet: look favorite dividend stock starbucks sbux price avg target upside apple aapl price avg target upside broadcom avgo price avg target upside
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6124266386032104}]
#
# Tweet: current holding since ppl asked gogo ntnx pd twtr crm roku onds avpt fsly aapl estc wday plan orgn bark mu vwe watching pin bought sold poor action amd docn rebuy zm baba dis insg myov pton z wynn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6797578930854797}]
#
# Tweet: biggest challenge getting active manager bmd sampp tsla pe x fy street eps x aapl amzn googl msft fb good exercise est float active mgrs might buy full weight unlikely happen yet
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5652581453323364}]
#
# Tweet: elite option watchlist shop c stop lulu c stop swing trade idea aapl c stop uber c stop
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7153967618942261}]
#
# Tweet: aapl ema demand hammer bounce aapl gt amp im eyeing c amp uber flag breakout uber gt amp im eyeing oct c
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9153544306755066}]
#
# Tweet: trouble deciding stock invest safe amp simple stock choose etf vanguard charles schwab voo schd qqq vti scha dsi growth goog amzn brka dividend aapl msft jnj wm
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8461177945137024}]
#
# Tweet: gtsif team w wba fight mtbi amp pstd full reportdisclaimer amc nio bbby btc mrk ddtg wallstreetbets amc aapl tsla crm coin hood sbux lyft grub amzn rwlk adbe fsr plug lcid
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8464614152908325}]
#
# Tweet: xclusivetriggers weekly fb call put aapl call put amzn call put nflx call put googl call put tsla call put roku call put zm call put
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8629067540168762}]
#
# Tweet: largest dividend payer microsoft msft atampt exxon mobil xom apple aapl jp morgan jpm based amount dividend paid
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9139209389686584}]
#
# Tweet: largest stock performed far today apple aapl microsoft msft google googl amazon amzn facebook fb tesla tsla taiwan semi tsm berkshire brkb nvidia nvda visa v jpm baba
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7740442156791687}]
#
# Tweet: innovation amp growth sell aapl buy tsla public safety sell fb buy tsla total addressable market sell nflx buy tsla antitrust sell goog buy tsla valuation sell nvda buy tsla founderrun sell msft buy tsla cool factor sell amzn buy tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.796661376953125}]
#
# Tweet: apple stock fall correction territory alltime high aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7492081522941589}]
#
# Tweet: fb aapl amzn msft googl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8451523780822754}]
#
# Tweet: mentioned ticker wsb via swaggy stock fb wish tsla baba aapl pltr amzn qqq tlry nvda
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8944928050041199}]
#
# Tweet: quality stock near aapl adbe amat apps crwd docu estc etsy fb meli pypl shop sq v yeti stock historically caught support built base near respective stock chart
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8907439708709717}]
#
# Tweet: aapl daily falling wedge
# Sentiment: [{'label': 'LABEL_1', 'score': 0.49324801564216614}]
#
# Tweet: overthinking investing long term stock pick face iphone aapl netflix nflx twitter twtr amazon amzn mcdonalds mcd target tgt walmart wmt use invest know
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7552300691604614}]
#
# Tweet: watch today marketoutlook video mentioned spy spx qqq iwm rut uup tnx tlt gld uso btc nflx rost tjx mrk aapl msft xlu xlre dbc nvda xlf xle bnd dvax
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8846448063850403}]
#
# Tweet: mentioned ticker wsb via swaggy stock pltr sdc tsla wish fb tlry nflx aapl coin amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9137256145477295}]
#
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx domino dpz amazon amzn microsoft msft apple aapl google googl sampp spy bond agg gold gld
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8630059957504272}]
#
# Tweet: warren buffetts top position aapl apple bac bank america axp american express ko coca cola khc kraft heinz currently much top position pay annual dividend aapl bac axp ko khc
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8963727951049805}]
#
# Tweet: largest market cap trillion aapl msft goog amzn btc fb tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8530707359313965}]
#
# Tweet: day gm catch even get close tsla day nokia flip phone overtake aapl iphone
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7900508046150208}]
#
# Tweet: retail capital flocked crypto bc last place theyre allowed make asymmetric upside investment one could buy msft aapl early amp see huge return public wait ipo first x already made private mkt
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5815050601959229}]
#
# Tweet: sure exact timing fb unfettered access data eventually come end itll aapl want reignite revenue
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8505465388298035}]
#
# Tweet: buy anything btc doge latest release get brand new aapl iphone bitplaza shopping app pay dogecoin bitcoin crypto doge cme
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7727524638175964}]
#
# Tweet: blessed another amazing day day amp week far traded aapl msft snap ba
# Sentiment: [{'label': 'LABEL_2', 'score': 0.981844425201416}]
#
# Tweet: buying shib like buying aapl steve job even born
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5106577277183533}]
#
# Tweet: wont imagine much longer use anemoi terminal youll able ride elephant back almost ready go live amc fb amzn aapl nflx goog msft tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6572234630584717}]
#
# Tweet: aapl aapl ready repeat
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8007479906082153}]
#
# Tweet: thats chart next day orlando tomorrow evening monday great rest week reviewed spy qqq iwm btc eth crm spot afrm penn aapl fubo net apps nflx dis upst snow sdc tsla
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6111333966255188}]
#
# Tweet: exclusivedutch antitrust authority find apple inapp payment system anticompetitive source aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7888908982276917}]
#
# Tweet: aapl plan car using iphone control ac seat radio bloomberg
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8954390287399292}]
#
# Tweet: confirmed earnings october aapl jpm tsm fb nflx snap clf bac dal sq pfe blk wfc wba intc googl f c dpz unh gm jnj nue cmc aa twtr ba qcom lrcx fyi amzn tsla amd baba msft scheduled earnings yet
# Sentiment: [{'label': 'LABEL_1', 'score': 0.922603189945221}]
#
# Tweet: top dividend growth stock abbv aapl avgo sbux v hd low jpm msft cost
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7852404117584229}]
#
# Tweet: friday lotto call idea break snap call break aapl call break snow call break tsla call
# Sentiment: [{'label': 'LABEL_1', 'score': 0.799644410610199}]
#
# Tweet: hm could humanity survive alphabet googl completely shutdown eliminate following google map youtube search android seo cooky amp related apps might important company maybe aapl v thought
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7307208776473999}]
#
# Tweet: lottofriday idea advised high risk xom c gt p lt pltr c gt p lt aapl c gt p lt qqq c gt p lt scale profit good luck like three extra pick
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5181096196174622}]
#
# Tweet: delighted share conversation journey investor power digital business like aapl nflx course evo
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8311932682991028}]
#
# Tweet: popular ticker search dot com thursday u treasury yield dow jones industrial avg tesla tsla sampp apple aapl algorand alibaba baba solana moderna mrna nasdaq composite
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8869225382804871}]
#
# Tweet: lotto friday xclusivetriggers fb call put aapl call put amzn call put nflx call put googl call put tsla call put msft call put spy
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8559783101081848}]
#
# Tweet: aapl reportedly building new regional headquarters los angeles
# Sentiment: [{'label': 'LABEL_1', 'score': 0.88646399974823}]
#
# Tweet: let clear aapl never car never fact id bet never car project titan happening year going anything tsla
# Sentiment: [{'label': 'LABEL_0', 'score': 0.4979647099971771}]
#
# Tweet: update apple tesla nio qqq spy roku squarecash draftkings nvidia bitcoin xpeng etsy amd content tech qqq aapl msft nvda amd mu growth tsla nio etsy roku sq xpev nndm arkk reopening spy dkng xom dis jblu crypto btc eth
# Sentiment: [{'label': 'LABEL_1', 'score': 0.893872082233429}]
#
# Tweet: jon youre smart guy favor spend minute modeling happens tsla rev ev adoption go current use whatever tsla ev share assumption want tsla rev pa aapl
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5288166403770447}]
#
# Tweet: mentioned ticker wsb via swaggy stock clov sdc tsla baba wish pltr gme aapl tlry qqq
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8868396282196045}]
#
# Tweet: mentioned ticker wsb via swaggy stock sdc tsla wish baba gme qqq amzn aapl nflx body note cei allowed wsb market cap billion current market cap million
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8978254199028015}]
#
# Tweet: singlehandedly built one five industry changed world past year cellphone aapl search goog eretailing amzn social networking fb ev tsla one quibble timing vision second none
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5411632061004639}]
#
# Tweet: mentioned ticker wsb via swaggy stock gme wish amzn fb aapl tsla nflx sdc dis qqq
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8895660638809204}]
#
# Tweet: used waste money nike cocacola new iphones buy nke ko aapl investing change mindset
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5271130800247192}]
#
# Tweet: stock amount profit last month saudi aramco b berkshire brkb b apple aapl b google googl b microsoft msft b
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7795737385749817}]
#
# Tweet: 𝑴𝒂𝒓𝒌𝒆𝒕 𝑬𝒗𝒂𝒍𝒖𝒂𝒕𝒊𝒐𝒏 𝑻𝒓𝒂𝒅𝒆 𝑰𝒅𝒆𝒂𝒔 sq amd tsla nio roku zm snow aapl amzn googl msft spy 𝙂𝙇 share winner tagging show like rt share flow week
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8887531161308289}]
#
# Tweet: xclusivetriggers fb call put aapl call put nflx call put tsla call put f call put amd call put also merch store live
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8996270298957825}]
#
# Tweet: turned computer first time month weekend came last night aapl pro good know still got game con cardiac rehab workout morning missed whole thing
# Sentiment: [{'label': 'LABEL_2', 'score': 0.62107914686203}]
#
# Tweet: im buy aapl share month
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8314906358718872}]
#
# Tweet: dividend paying company whose product used daily jnj aapl msft xom vz sbux tgt pep nke mo
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8684866428375244}]
#
# Tweet: apple ever hit per share id apple stock portfolio super bullish aapl amp aal american airline im aal investment since beginning pandemic
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8455701470375061}]
#
# Tweet: apple say apple event scheduled oct pdt aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6498847603797913}]
#
# Tweet: aapl holding special event october
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9263761043548584}]
#
# Tweet: apple aapl announced today hosting event october th starting pm est
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8302433490753174}]
#
# Tweet: breaking new aapl event october announced could apple car tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8154804706573486}]
#
# Tweet: lcid aapl announced event right lucid stream
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9293433427810669}]
#
# Tweet: aapl expected announce new macbooks airpods october event
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5455517768859863}]
#
# Tweet: first deal streaming medium giant nflx spot aapl duke duchess sussex looking become investing royalty esg deal originally reported story
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9306530952453613}]
#
# Tweet: think tsla idly sit aapl flirt creating electric car sorely mistaken believe tesla counter cell phone equivalent
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5060696005821228}]
#
# Tweet: tsla different era story aapl disrupter come better tech big guy nokia motorola bb slow react finally figure abandon old tech late tsla short seriously underestimating impact ice brand taint
# Sentiment: [{'label': 'LABEL_1', 'score': 0.4994499683380127}]
#
# Tweet: aapl apple poised slash iphone production goal due chip crunch apple supplier broadcom ti struggling deliver enough chip
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5304727554321289}]
#
# Tweet: tim cook supply chain expert aug th sold million worth aapl stock im big fan tim come
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8491662740707397}]
#
# Tweet: aapl reportedly expects produce million fewer iphones initially planned chip shortage
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6932495832443237}]
#
# Tweet: chip shortage due supply chain iphone lack demand last year pull forward minor upgrade iphone aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6576312184333801}]
#
# Tweet: find think weak close sampp may mean market next es_f spx ndx spy aapl tsla btc bitcoin fb es_f nq_f
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7320825457572937}]
#
# Tweet: smart bloomberg drop aapl news close
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9128948450088501}]
#
# Tweet: cnbc everything power brush aapl news pretty pathetic tsla news tire blew model driving today theyd talk safety nhtsa would involved consumer report would publish phil would air lora typing
# Sentiment: [{'label': 'LABEL_0', 'score': 0.6800404787063599}]
#
# Tweet: apple said slashing iphone production due semi chip shortage aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5397871136665344}]
#
# Tweet: would choose hold next year google googl bitcoin btc walmart wmt square sq b apple aapl tesla tsla berkshire brkb paypal pypl c microsoft msft ethereum eth disney dis draftkings dkng amazon amzn nvidia nvda jnj palantir pltr
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8831660747528076}]
#
# Tweet: week got even interesting nites report apple cutting iphone production unit due chip shortage aapl cant source part due size get first dibs supplier tech mfrs worse shape widespread impact
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5899019241333008}]
#
# Tweet: aapl stock never split would worth k rn imagine tsla year tesla bigger ecosystem apple energy software battery robot ai service car etc
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5963165760040283}]
#
# Tweet: top analyst say tesla appleesque buy stock new tsla tesla apple aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8153348565101624}]
#
# Tweet: apple likely cut iphone production due chip crunch aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6269283890724182}]
#
# Tweet: report tuesday indicated apple could cut iphone production much million unit supply problem analyst dont believe itll affect apple much aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5807504653930664}]
#
# Tweet: cant stop wont stop spy c chwy c chwy c fb c dkng lulu mgm c aapl c calling teamalgonaut like mm
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5644795894622803}]
#
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx domino dpz amazon amzn microsoft msft apple aapl google googl sampp spy bond agg gold gld
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8630059957504272}]
#
# Tweet: watchlist tomorrow abbv ivc prog gmbl slgg amp aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9295299649238586}]
#
# Tweet: excellent minute discussion analysis massive list today e qqq aapl amd amzn afrm googl nvda fb dkng q nflx shop roku fdx snap fslr sq blnk spot watch please retweet share thanks
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8794246315956116}]
#
# Tweet: ev inflection point tesla top mountain analyst new tsla tesla apple aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8975844383239746}]
#
# Tweet: today want make point paper portfolio look like today aapl amzn arkw goog tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8364286422729492}]
#
# Tweet: shanghai austin berlin enough tsla gt aapl revenue profit valuation
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8928713202476501}]
#
# Tweet: incredible spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c play given live free twitter requesting
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8177399039268494}]
#
# Tweet: spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c play given live free twitter okay
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7165898084640503}]
#
# Tweet: dd guy want tonight ah retweet aapl like ba retweets count vote
# Sentiment: [{'label': 'LABEL_1', 'score': 0.82234126329422}]
#
# Tweet: make life easier buy company lead respective industry aapl msft amzn sbux jnj mmm wait
# Sentiment: [{'label': 'LABEL_2', 'score': 0.656667172908783}]
#
# Tweet: moon amp mar spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c ba c free goal
# Sentiment: [{'label': 'LABEL_1', 'score': 0.869498610496521}]
#
# Tweet: patient investor rewarded amzn traded today amzn trade hd traded today hd trade aapl traded today aapl trade avgo traded today avgo trade
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7815647125244141}]
#
# Tweet: blessed day amp week traded took uber swing called yesterday dkng nvda penn aapl chwy bbig ran back back day
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8498415946960449}]
#
# Tweet: apple watch series arrives tomorrow biggest update larger display size last year price point declare aapl winner wrist significant growth potential ahead
# Sentiment: [{'label': 'LABEL_2', 'score': 0.937980592250824}]
#
# Tweet: aapl aapl weekly candle looking good
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9658324122428894}]
#
# Tweet: alright everyone thats tonight good one make sure check trade idea video today reviewed following chart feed spy roku tsla amd nvda nndm nio spot maxr penn dkng aapl plby fubo twtr
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8770829439163208}]
#
# Tweet: watch today marketoutlook video mentioned spy spx qqq iwm rut uup tnx tlt gld uso btc xlre xlf xle xlv xly sgms swx iep crm mdb bill wba msft aapl c wfc blk bac etn emr xlk orcl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8762552738189697}]
#
# Tweet: aapl day higher report million phone production cut stock go bad news bullish signal
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5862287878990173}]
#
# Tweet: numerous investor missed x return top growth stock bc waiting cheaper valuation however high quality growth stock tend stay expensive time amzn aapl nflx adbe nvda amd
# Sentiment: [{'label': 'LABEL_1', 'score': 0.4794733226299286}]
#
# Tweet: amazing week spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c ba c scalp free goal smash
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9032204747200012}]
#
# Tweet: look around usevisit find high quality dividend stock jnj aapl msft xom ko v nke sbux mcd
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7598638534545898}]
#
# Tweet: astronomical week spy c chwy c fb c dkng lulu mgm c aapl c rblx c ba c scalp free like ba upside pt
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8899344205856323}]
#
# Tweet: warren buffett berkshire hathaway brkb largest holding apple aapl b bank america bac b american express axp b cocacola ko b kraft heinz khc b moody mco b verizon vz b u bancorp usb b davita dva b chtr b
# Sentiment: [{'label': 'LABEL_1', 'score': 0.885059118270874}]
#
# Tweet: hope chart helpful morning great saturday lot info weekend update spy start qqq iwm btc eth tsla nio aapl nvda amd penn
# Sentiment: [{'label': 'LABEL_2', 'score': 0.923477292060852}]
#
# Tweet: portfolio holding year aapl apple pltr palantir arkg ada cardano b se sea ltd amzn amazon qqq eth ethereum c googl google upst upstart voo sol solana tsla tesla sofi sofi arkk btc bitcoin
# Sentiment: [{'label': 'LABEL_1', 'score': 0.874311625957489}]
#
# Tweet: aapl weekly catching bid right demand zone
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8965343236923218}]
#
# Tweet: got monthly substack newsletter sub giveaway likecommentretweet chance win must following spy spx aapl amzn googl tsla qqq snap nio pltr sq gme amc mst nflx fb roku
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6922245025634766}]
#
# Tweet: new netflix movie theater palisade apple territory love nflx buying theater showing show movie add movie pa tier aapl
# Sentiment: [{'label': 'LABEL_2', 'score': 0.83660888671875}]
#
# Tweet: glove im literally spending whatever take painfully large amount lawyer fee able actually kind open mouth engage founding father envisioned free speech amc gme bb fb aapl amzn goog msft
# Sentiment: [{'label': 'LABEL_1', 'score': 0.554564893245697}]
#
# Tweet: spot aapl amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8583965301513672}]
#
# Tweet: chart pattern cheat sheet optionstrading spy aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8360997438430786}]
#
# Tweet: monday relatively quiet day growth stock well noteworthy aapl event googl event tost quiet period expiration riot investor tour
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5311209559440613}]
#
# Tweet: weekly watchlist baba c gt p lt amd c gt p lt tsla c gt p lt xpev c gt p lt c gt p lt aapl c gt p lt unlock favorite swing setup
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9124520421028137}]
#
# Tweet: public watchlist sq c coin c aapl c pton p baba p chart amp bonus pick posted later tonight good luck trader
# Sentiment: [{'label': 'LABEL_2', 'score': 0.511956512928009}]
#
# Tweet: mentioned ticker wsb via swaggy stock tsla aapl amzn gme fb wish nflx upst sofi bb
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9015944600105286}]
#
# Tweet: lts weekly watchlist solid week ton setup good luck everyone feel free reach question may aapl pypl fb sq spot shop googl tsla nvda amd amzn msft baba upst cat spy spx qqq
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8510168790817261}]
#
# Tweet: panda weekly watchlist aapl c p msft c p sq c p amzn c coin c amd c
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9038417935371399}]
#
# Tweet: opc top aapl gt supply sq gt downtrend break
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8572953939437866}]
#
# Tweet: breaking apple supplier foxconn unveils ev including sedan suv bus foxconn plan begin mass production electric car u thailand talk possible location europe well chairman liu said earlier year aapl tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8768543601036072}]
#
# Tweet: another exciting week stonk market coming monday aapl event wednesday tsla earnings friday fsd beta go everyone plus existing tester
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9722654223442078}]
#
# Tweet: analyst consistently get wrong proper comparison tsla v oems walking dead tsla v googl aapl amzn bidu rivn lcid bunch private working autonomous vehicle
# Sentiment: [{'label': 'LABEL_0', 'score': 0.6879093647003174}]
#
# Tweet: k portfolio tech aapl msft amd dividend xom mo spg growth tsla sq pltr index qqq dia spy consumer ko mcd cost safety gld slv tlt next cash hand opportunity arise dca would change comment
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8761700391769409}]
#
# Tweet: build portfolio pay monthly dividend stock would cover every month mo low jnj ko sbux hd csco abbv mmm jpm aapl avgo
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8876161575317383}]
#
# Tweet: dumped tdoc today lost patience take buy sq aapl
# Sentiment: [{'label': 'LABEL_0', 'score': 0.8157880902290344}]
#
# Tweet: maybe another color option innovation aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8238937258720398}]
#
# Tweet: year incredible growth aapl
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9080260396003723}]
#
# Tweet: jim chanos tsla short thesis tsla trade x eps tsla valuation greater auto mnfrs combined one need value growth stock npv earnings two competitor list need incl aapl googl amzn bidu rivn av maker etc
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8499962687492371}]
#
# Tweet: told aapl product changed color
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7251543402671814}]
#
# Tweet: new rd generation apple aapl airpods start
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7203765511512756}]
#
# Tweet: aapl apple unveils pro chip first pro chip designed mac also introducing new macbook pro airpods airpods spatial audio magnetic charging
# Sentiment: [{'label': 'LABEL_2', 'score': 0.7952826023101807}]
#
# Tweet: apple cult like following people continually upgrade airpods phone ipads macbooks best thing share company buy aapl
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8822294473648071}]
#
# Tweet: aapl treat
# Sentiment: [{'label': 'LABEL_1', 'score': 0.600761890411377}]
#
# Tweet: phase fb phase ad platform phase shopping payment platform phase arvr hardware platform phase metaverse app store basically fb becomes fb amzn aapl one company
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8925979733467102}]
#
# Tweet: today hosted lastest product launch appleevent soon itll possible buy aapl anticipate event like one today might impact stock price get ready decentralized stock platform launching q
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6590470671653748}]
#
# Tweet: apple think new color innovation aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5047600269317627}]
#
# Tweet: ok pro chip great ill buying new macbook soon need whole movie aapl
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9439547657966614}]
#
# Tweet: today play amd c hit nio swing c hit coin c hit aapl c hit msft c hit
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9259721636772156}]
#
# Tweet: three force supporting sampp helped susmitas superb aapl airpods presentation stock closed right dollar cinch background open es_f spx ndx spy es_f nq_f zc_f cl_f oott
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5535961985588074}]
#
# Tweet: new mac book look great apple great lineup product going holiday season expect record revenue profit although innovation evolution product great aapl
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9822868704795837}]
#
# Tweet: aapl long hold new high axpected
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5259214043617249}]
#
# Tweet: update apple tesla amazon nvidia spy qqq amd disney amc micron bitcoin ethereum content technology aapl amzn amd nvda msft tsla enph mu intc reopening inflation dis amc uuuu cper vale crypto btc eth mara riot mstr
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8830631375312805}]
#
# Tweet: doubled pltr investment currently holding k worth truly believe one many trillion dollar company next decade good luck always dd good luck pltr nio tsla aapl coin tdoc fubo
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9290916919708252}]
#
# Tweet: great collaboration amp analysis e qqq aapl amd amzn ba bidu mrna msft nflx nio fb roku shop snap snow cat bynd tsla please retweet find useful
# Sentiment: [{'label': 'LABEL_2', 'score': 0.764758825302124}]
#
# Tweet: apple aapl luca maestro bond king gentleman know sell bond
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9073047041893005}]
#
# Tweet: top stock purchased congress ice msft amzn nflx crm pypl aapl usac amza nvda link
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9102111458778381}]
#
# Tweet: tgt say doubling number aapl shop store
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8611400723457336}]
#
# Tweet: top stock member congress aapl msft boa dis pfe pfizer hmm jnj ge xom goog
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8842594027519226}]
#
# Tweet: friendly reminder aapl largest public company world projecting sell airpods lose one every month tim apple win
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5423592925071716}]
#
# Tweet: traded wife mac air new macbook impressive machine cant wait test apple great line holiday long aapl forever
# Sentiment: [{'label': 'LABEL_2', 'score': 0.978927493095398}]
#
# Tweet: daily recap monster day cost c holding upst p pin c zm c quick scalp aapl c twtr c mrvl mat swing holding follow flow get bag
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7215715050697327}]
#
# Tweet: another big day winner baba swing lrcx swing aapl rf baba rf snap rf loss ba sfbeta zm swing ccl x today overall slow day stayed patient amp fluid today trading desk view
# Sentiment: [{'label': 'LABEL_2', 'score': 0.48927009105682373}]
#
# Tweet: officially greed territory fb aapl amzn googl msft
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8854608535766602}]
#
# Tweet: guy long aapl short fb evil always win
# Sentiment: [{'label': 'LABEL_0', 'score': 0.483504056930542}]
#
# Tweet: watch today marketoutlook video mentioned spy spx qqq iwm rut uup tnx tlt gld uso btc gbtc bito btf bitcoin ul aapl ulta nflx tsla el dividendaristocrats pg jnj clx kmb
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8730036020278931}]
#
# Tweet: lot strong setup posted tonight see tomorrow reviewed penn blnk maxr grwg fubo pton wish fslr acb ddd spot spy iwm fsly aapl mj
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7342579960823059}]
#
# Tweet: wonderful discussion amp analysis e qqq baba aapl amd amzn ba bidu mrna msft nflx nio fb roku shop snap snow cat bynd tsla dis please like retweet find useful
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6695243120193481}]
#
# Tweet: new wednesday post alert megacap tech stock make break market earnings loom fb report oct msft report oct googl report oct aapl report oct amzn report oct
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8361066579818726}]
#
# Tweet: maga custom index msft aapl googl amzn new demark sequential sell countdown previous two time saw shortly signal
# Sentiment: [{'label': 'LABEL_1', 'score': 0.90302973985672}]
#
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx domino dpz amazon amzn microsoft msft apple aapl google googl sampp spy bond agg gold gld
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8630059957504272}]
#
# Tweet: aapl flow highly bullish whale adding c
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6798914670944214}]
#
# Tweet: strong dividend stock sbux hd v jnj abbv mmm aapl rtx ko
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7685790061950684}]
#
# Tweet: watchlist tomorrow aapl mrk pin cxdc iht
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9297451376914978}]
#
# Tweet: asked year old son give company like explaining company picked tsla aapl rblx year old better investor
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7645260095596313}]
#
# Tweet: research think pypl move attempting acquire pin defense afrm pypl must felt serious threat afrm partnering w shop wmt amzn tgt hd pton aapl ssnlf etc long list afrm gon na blowout er
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5522134900093079}]
#
# Tweet: aapl ad fb ad
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8280037045478821}]
#
# Tweet: considering selling aapl share nio amp tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8969137072563171}]
#
# Tweet: b net profit apple aapl still cant make fucking battery worth shit
# Sentiment: [{'label': 'LABEL_0', 'score': 0.959681510925293}]
#
# Tweet: q dividend rest year big name like xom vz aapl sbux spg intc jnj pfe wba nly bp
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8718726634979248}]
#
# Tweet: isnt bad much trading go congress ramification take senator james inhofe briefed devastation covid jan sold k ie bam c dhr intu aapl pypl doj investigated nothing happened
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6994496583938599}]
#
# Tweet: tsla bull case stock talk tesla q demand v supply constraint amp new gigafactories berlin amp austin plus fb rebrand aapl airpods amp msft earnings preview
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8654109239578247}]
#
# Tweet: dont give fuck jay buy aapl call put
# Sentiment: [{'label': 'LABEL_0', 'score': 0.8367398977279663}]
#
# Tweet: say sampp brand getting profile fueled hbar face melt hbar hold tsla aapl msft amzn dis
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8037956953048706}]
#
# Tweet: analysis year ago aapl change adtech ecosystem updating premium sub think might happen rest er quarter tell snap wont one affected simply first report
# Sentiment: [{'label': 'LABEL_1', 'score': 0.830061674118042}]
#
# Tweet: nfl reportedly likely make sunday ticket deal either aapl amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9413257241249084}]
#
# Tweet: nq_f target amp es_f rty_f ym_f tech lead based nq_f one buy spy amp qqq humble warning lowerside limited time frame wil revealed depending amp rt nqestslaamznaapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8195456862449646}]
#
# Tweet: total time reach billion market cap tsla year month goog year month amzn year month aapl year month msft year month
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8100481033325195}]
#
# Tweet: big cap tech hurt snap revelation apple hurting ad business protecting privacy mean fb goog amzn issue especially facebook aapl
# Sentiment: [{'label': 'LABEL_0', 'score': 0.7014666795730591}]
#
# Tweet: cant invest right yet ate every day week cant invest right yet purchase latest aapl iphone every year cant invest right yet bought new car cant invest right yet ran huge bar tab
# Sentiment: [{'label': 'LABEL_0', 'score': 0.7146483063697815}]
#
# Tweet: top ten global market cap usd cryptos combined apple aapl microsoft msft saudi aramco alphabet goog amazon amzn bitcoin facebook fb b tesla tsla b berkshire hathaway brka b included gold
# Sentiment: [{'label': 'LABEL_1', 'score': 0.875552237033844}]
#
# Tweet: roku aapl snap googl take everyone else idfa change still u tripled ad biz mo take basically bc seems legit
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6790086030960083}]
#
# Tweet: scrolling feed idea dwac never heard trade aapl today min enjoy ur weekend
# Sentiment: [{'label': 'LABEL_2', 'score': 0.7029603123664856}]
#
# Tweet: xclusivetriggers apply trading week fb aapl nflx tsla amzn snap se mstr gain totaling combined
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8852362036705017}]
#
# Tweet: hope everyone nice friday night new weekend update timestamps spy start qqq iwm btc eth solana tsla aapl roku sq amd atvi
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8832442760467529}]
#
# Tweet: next week earnings going fun monday fb tuesday msft googl twtr amd wednesday twlo ba tdoc f algn thursday aapl amzn shop team many others
# Sentiment: [{'label': 'LABEL_2', 'score': 0.7672817707061768}]
#
# Tweet: upcoming earnings report week october th xom abev aapl sbux mrk cat avt asx bud amzn ebay gm ko mcd f ba db bmy bg amd ge googl twtr ups goog msft fb spy qqq free week benzinga pro
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9076542854309082}]
#
# Tweet: year price increase soon appear well tsla gt aapl revenue tsla gt aapl margin tsla gt aapl cash flow tsla gt aapl valuation
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6666585206985474}]
#
# Tweet: preparing present aapl conference
# Sentiment: [{'label': 'LABEL_1', 'score': 0.898290753364563}]
#
# Tweet: go massive earnings week fb ups ge goog v twtr hood amd lly q rtx ba gm ko mcd spot teva twlo f algn upwk ebay tdoc shop cat aapl amzn sbux ostk xom abbv mstr name week
# Sentiment: [{'label': 'LABEL_1', 'score': 0.857099175453186}]
#
# Tweet: fb shareholder hope multiple rerate higher better keep expectation low year mr market valued aapl almost like dying business hard imagine may inflict fb long time period aapl fcf cagr fb fcf cagr
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6087567806243896}]
#
# Tweet: aapl fb googl snap
# Sentiment: [{'label': 'LABEL_1', 'score': 0.866994321346283}]
#
# Tweet: big week tech earnings ahead mon fb tues msft googl amd twtr hood v wed ba mcd ko gm f thurs aapl amzn shop sbux cat fri xom cvx rcl dia spy qqq iwm vix
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8090567588806152}]
#
# Tweet: next week huge week tech er season im focused lc atom im also watch broad market impact fb amd enph googl msft aapl twlo amzn shop team
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5551745891571045}]
#
# Tweet: best dividenddividend growth stock money buy pep hd ko msft mmm aapl jpm pg jnj mcd spg cost v vz sbux nke xom mo wmt bac intc pfe wba irm add watchlist research build true passive income
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6813797354698181}]
#
# Tweet: largest stock performed far apple aapl microsoft msft google googl amazon amzn facebook fb tesla tsla berkshire brkb nvidia nvda taiwan semi tsm jpmorgan jpm alibaba baba visa v
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8218252658843994}]
#
# Tweet: aapl might easiest er run play trade idea aapl c premium open lower
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8296388387680054}]
#
# Tweet: enjoy writing market enjoy reading market subscribe blog dwac mara coin aapl snap fb cost tsla goog bitcoin twtr tic top
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8974326252937317}]
#
# Tweet: big earnings week ahead name like amd aapl amzn shop twtr v fb reporting guy watching
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6393517255783081}]
#
# Tweet: public weekly watchlist aapl c atvi c fdx c jpm c nvda c chart bonus pick uploaded later tonight good luck trader
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5289187431335449}]
#
# Tweet: week notable earnings via mon fb kmb tzoo tues msft googl amd twtr hood v txn ups ge mmm lmt wed ba mcd ko gm f spot tdoc ebay twlo upwk thurs aapl amzn shop sbux cat mo mstr x fri xom cvx rcl abbv cl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8405861258506775}]
#
# Tweet: quick update thread first tweet million impression twitter promoted tweet wouldve cost k day look earnings goog aapl etc imagine much press afford
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5166676640510559}]
#
# Tweet: nio tsla aapl fortune stored cryptos fun company real tangible product line ive accumulating aapl year holding tsla since march nio month
# Sentiment: [{'label': 'LABEL_2', 'score': 0.62950599193573}]
#
# Tweet: market evaluation 𝑻𝒓𝒂𝒅𝒆 𝑰𝒅𝒆𝒂𝒔 sq amd tsla nio roku zm snow aapl amzn googl msft spy 𝗚𝗼𝗼𝗱 𝗟𝘂𝗰𝗸 share trade tagging amp letting share flow show like rt enjoy
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7107404470443726}]
#
# Tweet: aapl put
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6666374206542969}]
#
# Tweet: q earnings kick full swing week aapl msft amzn googl fb twtr reporting biggest focus whether weak snap guidance last week following aapl io privacy change oneoff advertiser cutting back social medium advertising
# Sentiment: [{'label': 'LABEL_1', 'score': 0.727484941482544}]
#
# Tweet: dividend stock come shape size low yieldhigher growth aapl msft v hd de moderate yield ko pep mmm jnj higher yield abbv xom cvx vz reit stor irm psa amt type invest
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8676361441612244}]
#
# Tweet: long took asset reach market cap milestone bitcoin btc year tesla tsla year google googl year amazon amzn year apple aapl year microsoft msft year
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6580594182014465}]
#
# Tweet: get new aapl apple watch series bitplaza app pay btc doge ltc based usa international shipping friendly customer support bitcoin dogecoin litecoin accepted crypto dogearmy litecoinfam
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5715786218643188}]
#
# Tweet: tsla crossing today amp fb falling faang renamed gambat qe forever world new bogey googl aapl msft btc amzn tsla cc
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8672788143157959}]
#
# Tweet: market capitalization feel justifiable given macro environment aapl msft goog amzn tsla bitcoin
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5033464431762695}]
#
# Tweet: apple likely face doj antitrust suit information aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8980322480201721}]
#
# Tweet: aapl reportedly likely face antitrust suit department justice
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7900665402412415}]
#
# Tweet: flash back stock trend several name headlining news today gain since fb tsla googl aapl nvda original blog
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6433204412460327}]
#
# Tweet: stock think perfect small account stock option cheap premium volume tight bid ask spread aapl snap xpev lcid snap spy dis nio aal
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5161474347114563}]
#
# Tweet: apple likely face doj antitrust suit information aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8980322480201721}]
#
# Tweet: aapl max beat amd radeon pro wx affinity benchmark test
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9260680675506592}]
#
# Tweet: earn monthly dividend income stock mo low hd ko sbux msft stor aapl mmm csco pg avgo
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8240278959274292}]
#
# Tweet: apple delaying new macbook pro preorders warning device wouldnt arrive today appleinsider aapl
# Sentiment: [{'label': 'LABEL_0', 'score': 0.7034471035003662}]
#
# Tweet: aapl granted patent smartglasses vr headset use direct retinal projector system
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8054601550102234}]
#
# Tweet: last year uranium urnm coal arch ag mo oil xop copper teck metal xme sampp equal weight apple aapl facebook fb amazon amzn bond tlt equalweight gt big tech via
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8694026470184326}]
#
# Tweet: getting ready aapl thursday night bottom line think investor going look past supply chain issue focus sustained step demand thanks accelerating digital transformation
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5686944127082825}]
#
# Tweet: amzn gt msft gt aapl gt goog gtgtgtgtgtgtgtgtgt fb
# Sentiment: [{'label': 'LABEL_1', 'score': 0.827918529510498}]
#
# Tweet: im sick amp tired people fintwit misleading retail trader isnt game semblance responsibility spent morning arguing amc could worth aapl amp googl said pricetarget realistic logical
# Sentiment: [{'label': 'LABEL_0', 'score': 0.853918731212616}]
#
# Tweet: remember titan msft aapl googl amzn tsla
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8817723393440247}]
#
# Tweet: announce fiscal result fourth quarter oct likely break quarterly record expect aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5173194408416748}]
#
# Tweet: pelosi democrat close agreement topline biden bill update aapl position earnings
# Sentiment: [{'label': 'LABEL_1', 'score': 0.925984263420105}]
#
# Tweet: still shit coin dont sweat millionaire retrospectively tesla stock amazon aapl pre split cry million going get anywhere good luck bud fake
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5489568710327148}]
#
# Tweet: word street people selling high risk meme stock aapl amp amzn buy low risk blue chip crypto called shib
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7573039531707764}]
#
# Tweet: january posted conviction ranking stock portfolio top order w ytd return msft amzn tsla aapl nvda crwd represent portfolio good name keep winning focus
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8427068591117859}]
#
# Tweet: guarantee msft googl amp qqq september high likely aapl lulling u sleep turn rotation aapl ended wave correction retracement wave aapl gt wave target
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8996042609214783}]
#
# Tweet: qqq daily shooting star making aths double topping aapl amzn decide taking number earnings use imagination well get reversal confirmation
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6889861822128296}]
#
# Tweet: stock hold year ko aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.832612931728363}]
#
# Tweet: market cap club member performed since aapl msft googl amzn tsla fb
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9145878553390503}]
#
# Tweet: mimi greatest investor ill probably ever know put ira goog aapl rest spy brkb since passed kid pulled half starting value balance today x maybe lesson ngaf risktaking
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5756124258041382}]
#
# Tweet: trailing year cagr msft aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7817771434783936}]
#
# Tweet: ccxi wm f c ivc tsla wmt cv rdib astr shop otrk lcid wtrh sxtc bynd spce aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7969933748245239}]
#
# Tweet: msft may overtake aapl valuable company world week microsoft le away apple
# Sentiment: [{'label': 'LABEL_1', 'score': 0.641925036907196}]
#
# Tweet: huge club day amzn aapl stay close
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5275750756263733}]
#
# Tweet: year btc year tsla year aapl taught important thing large return come time market accumulate quality asset recognized world fud near term fundamental outweigh long term
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5457725524902344}]
#
# Tweet: aapl cloth
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7018275260925293}]
#
# Tweet: usa gdp slowed data point remains unknown afaic aapl eps key level may decide next whether hold point sampp upon close tsla aapl sampp
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8443914651870728}]
#
# Tweet: icymi mkt call amp discussed setup broad market big tech msft googl amzn aapl tesla tsla rally amp car htzz plus classic comedy cbw end sponsored amp
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8940989375114441}]
#
# Tweet: googl aapl msft mvrs amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8580870032310486}]
#
# Tweet: hearing cathie wood bought million kopn share cheap stock lowest year specializes manufacturing wearable tech could relate fb vr aapl earnings stock double near future share must
# ...
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8460286855697632}]
#
# Tweet: performace largest stock since went public msft microsoft amzn amazon aapl apple googl google
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6974769234657288}]
#
# Tweet: invested ipo would msft microsoft gt million amzn amazon gt million aapl apple gt million googl google gt
# Sentiment: [{'label': 'LABEL_1', 'score': 0.820837676525116}]
#
# Tweet: since adopted bitcoin standard mstr btc goog aapl orcl msft sampp ibm nasdaq gold bond amzn crm silver meta sap nflx
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8937137126922607}]
#
# Tweet: amzn generates operating profit aws
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6703211665153503}]
#
# Tweet: top holding amzn msft v appl jnj sbux working bring schd top allocation hopefully december whats top holding
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9119495153427124}]
#
# Tweet: share u tv time streaming cable broadcast including gaming streaming breakdown total netflix nflx youtube goog hulu prime video amzn disney dis streaming
# Sentiment: [{'label': 'LABEL_1', 'score': 0.912780225276947}]
#
# Tweet: estimated bloomberg week post cpi jeff bezoss amzn lost billion elon musk lost billion fortune mark zuckerberg larry page sergey brin steve ballmer declined billion warren buffett lost billion
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5172996520996094}]
#
# Tweet: top shorted sampp stock apple aapl tesla tsla microsoft msft google googl goog amazon amzn visa v mmm alibaba baba occidental petro oxy facebook meta
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7832858562469482}]
#
# Tweet: amzn amzn new one never seen many volume gap
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7931999564170837}]
#
# Tweet: ready check option play morning retweets ready let go spy qqq aapl amzn tsla meta baba googl msft amd
# Sentiment: [{'label': 'LABEL_1', 'score': 0.882753312587738}]
#
# Tweet: since microstrategy adopted bitcoin standard mstr btc goog aapl orcl msft sp ibm nasdaq gold bond amzn crm silver meta sap nflx source
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9032790660858154}]
#
# Tweet: big week ahead thanks checking stickynote amd let stay lane shorted key level nflx wow looking strong buy dip amzn bad week look awful msft week low
# Sentiment: [{'label': 'LABEL_2', 'score': 0.8009697198867798}]
#
# Tweet: amzn still position growth high coming year aws ad business logistics service business two segment still early inning amzn long amzn
# Sentiment: [{'label': 'LABEL_2', 'score': 0.71216881275177}]
#
# Tweet: return twtr tsla aapl gme amzn msft goog team crm snow amd adbe pypl etsy mrna nvda meta spot zm sq nflx snap shop
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8857302665710449}]
#
# Tweet: return twtr tsla aapl amzn msft goog crm meta spot zm sq nflx snap shop mike tyson nft could seen coming
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8979387283325195}]
#
# Tweet: amazon remove solar april june solar panel atop amzn fulfillment center caught fireexploded least different time fire caused undetermined electrical event roofmounted solar system
# Sentiment: [{'label': 'LABEL_0', 'score': 0.7403171062469482}]
#
# Tweet: many following post hope worth time energy sharing input thank spy qqq amzn meta tsla baba googl nvda amd sq snow
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9027007222175598}]
#
# Tweet: amazon say prime signups topped cyber monday nfl game amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7602915167808533}]
#
# Tweet: thanks looking today stickynote low volume day ahead tomorrow patience f b unexpected cost good whats next pypl downgrade plus heading towards amd patience pay long amzn msft
# Sentiment: [{'label': 'LABEL_2', 'score': 0.784299910068512}]
#
# Tweet: sell tech stock goog aapl amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7496954202651978}]
#
# Tweet: ytd return amzn msft goog crm isrg wix idxx adbe net nvda meta spot zm nflx mtch sq asan roku fvrr twlo se u snap shop cvna
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8637033104896545}]
#
# Tweet: amazon amzn cargo airline growing slowest pace since start pandemic per bloomberg
# Sentiment: [{'label': 'LABEL_0', 'score': 0.49294328689575195}]
#
# Tweet: pltr better msft amzn goog ai software sale ranking little ahead giant
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6902288198471069}]
#
# Tweet: twitch amzn banned streaming gambling site include slot roulette dice game arent licensed either u jurisdiction provide sufficient consumer protection
# Sentiment: [{'label': 'LABEL_0', 'score': 0.7251479625701904}]
#
# Tweet: dotcom bubble already happened dont see tsla v growth stock amp faang yoy tsla se rblx roku sq tdoc fb amzn aapl nflx googl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5213846564292908}]
#
# Tweet: amzn biggest three hour u prime signups ever thursday chiefschargers game
# Sentiment: [{'label': 'LABEL_1', 'score': 0.51296466588974}]
#
# Tweet: various way invest style suit best dividend foundation stock pep jnj pg pfe dividend growth stock trow avgo cost hd msft growth stock nvda amzn tsla googl aapl
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7913162112236023}]
#
# Tweet: start tsla amzn aapl would master stock put necessary screen time youre learning dont make harder need
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7269136309623718}]
#
# Tweet: news stablecoin legislation twitch amzn ban crypto gambling cv wmt opioid settlement bynd coo suspended spanberger digital disclosure gps cut htz x gm nvda next gen gpus gdpnow fine future
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6485381126403809}]
#
# Tweet: amzn key stock still holding support bear flagto confirm immediate downside need breakdown
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7764566540718079}]
#
# Tweet: amzn managed close right support candleit matter time imoan equal length target previous drop would put sometime next year
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8602880835533142}]
#
# Tweet: amzn june low googl hit new ytd low today google also year date amazon seems odd considering amzn consensus eps collapsed zero year would rather
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5001142621040344}]
#
# Tweet: largest stock performed far apple aapl microsoft msft google googl amazon amzn tesla tsla berkshire brkb unitedhealth unh jnj tsm visa v facebook meta exxon xom
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7852327823638916}]
#
# Tweet: hit like share free play tomorrow spy qqq aapl amzn meta tsla nvda amd sq se googl etsy baba twlo
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8802017569541931}]
#
# Tweet: amazon routinely hired dangerous trucking company wsj analysis find wsj amzn
# Sentiment: [{'label': 'LABEL_0', 'score': 0.6456829905509949}]
#
# Tweet: bought nvda goog amzn longer term
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8875385522842407}]
#
# Tweet: would love see weekly candle close support amzn look pretty good continuation downward breaking bear flag
# Sentiment: [{'label': 'LABEL_2', 'score': 0.9496390223503113}]
#
# Tweet: yeartodate performance fb amzn aapl nflx googl msft tsla f pypl faang stock aside aapl bear market territory fact spx isnt miracle
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5701990127563477}]
#
# Tweet: cost growing faster aapl goog meta amzn msft growing faster without leverage without dilution also none company sell hot dog drink
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6047020554542542}]
#
# Tweet: amazon amzn stock surged announced four new version fire tablet starting amazon amzn technology stock investing stockmarket
# Sentiment: [{'label': 'LABEL_2', 'score': 0.7612730264663696}]
#
# Tweet: fdx isnt weakening global demand shipping theyre losing market share amzn dont want come say theyre trying buy time probably little late people know probably got long time ago stock done
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5223031640052795}]
#
# Tweet: jeff bezos office amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8916659951210022}]
#
# Tweet: crossed k year date trading profit today made k day trading amzn post full breakdown later
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8728766441345215}]
#
# Tweet: ai software sale company pltr b msft b ibm b amzn aws b googl b ai software
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8691303730010986}]
#
# Tweet: greatest wealth created bear market opportunity buy company discount buy company best sector amazon amzn apple aapl home depot hd chipotle cmg mcdonalds mcd microsoft msft waste management wm
# Sentiment: [{'label': 'LABEL_2', 'score': 0.7819668650627136}]
#
# Tweet: return twtr aapl tsla msft goog amzn gme crm team snow adbe mrna amd pypl etsy nvda meta zm spot nflx sq snap shop
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8801272511482239}]
#
# Tweet: since adopted bitcoin standard btc mstr goog aapl orcl msft sampp ibm nasdaq gold bond crm amzn silver meta sap nflx
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8934032320976257}]
#
# Tweet: use make day trading tsla video must watch learn replicate watch video spx spy shop nvda amzn nflx roku tsla nio xpev gme amc bynd qcom abnb mrna rblx upst
# Sentiment: [{'label': 'LABEL_1', 'score': 0.829800546169281}]
#
# Tweet: posted option flow data spy qqq iwm data shared tomorrow give following thank amzn aapl nflx googl baba meta sq se ttd v twlo etsy
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8650963306427002}]
#
# Tweet: yeartodate performance fb aapl amzn nflx googl tsla msft dis nvda baba pypl imagine damage housing price crash next bubble officially bursting
# Sentiment: [{'label': 'LABEL_0', 'score': 0.5892486572265625}]
#
# Tweet: warren buffett th richest american worth billion recommends investing sampp index fund sampp made stock apple aapl microsoft msft google goog googl amazon amzn tesla tsla let discus
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7131100296974182}]
#
# Tweet: tsla trade idea sept c closed let see tsla bottom near set bounce week put work aapl arkk amd amzn ba meta msft nflx nio es_f nvda qqq mdb spx spy tgt tsla zm
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8776991367340088}]
#
# Tweet: option trading watchlist amzn c gt amd c gt meta p lt market remain weak room downside short technical bounce possible name exploit opportunity flow via unusual whale optionstrading
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7820529341697693}]
#
# Tweet: amazon amzn hold midoctober sale capture holiday spending per reuters
# Sentiment: [{'label': 'LABEL_1', 'score': 0.888703465461731}]
#
# Tweet: inflation reduction act impose minimum tax large corporation brkb amzn f ebay mrna nvda set hit hardest according unc tax center source
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7175761461257935}]
#
# Tweet: option trading watchlist amzn scratch amd c gt meta p lt conservative monday market take direction well see volatility strategize exit always mitigate risk stop flow unusual whale stock see thread
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8915019631385803}]
#
# Tweet: stock plan buy hold next year aapl msft goog amzn v holding
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9154123663902283}]
#
# Tweet: many name held spx far le june yet spx june th aapl amzn sampp aapl amzn sampp name turn lower real sell begin
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8446653485298157}]
#
# Tweet: option trading watchlist amzn p lt narrow list one name radar market weak range bound absent catalyst thurs flow via unusual whale revisit optionstrading stock
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8183227777481079}]
#
# Tweet: largest public company aapl msft amzn tsla brka unh v jnj trade lower earnings yield real cash yield yr treasury today stand
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7831106185913086}]
#
# Tweet: would support view still lot capitalmoney trying hide old mega cap tech leader aaplamznodds see downside say cop raid brothel even piano player get arrested
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5879467725753784}]
#
# Tweet: key event tomorrow amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.9070712924003601}]
#
# Tweet: fact amzn aapl tsla havent made week low broader index scare shit bull
# Sentiment: [{'label': 'LABEL_0', 'score': 0.756139874458313}]
#
# Tweet: free option idea scale profit spy cgt pltinsane ob amd cgt plt msft cgt plt amzn cgt plt use ibkr fully automate order see bonus
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7576076984405518}]
#
# Tweet: top tech stock highest share buyback past quarter aapl googl msft meta chtr nvda wmt amzn klac v csco
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5869099497795105}]
#
# Tweet: good morning trader thanks looking stickynote pls retweet aapl slow production good pre mkt low amzn consumer weak stock fade pop amd watching low could hold lyft hiring freeze bad sign
# Sentiment: [{'label': 'LABEL_2', 'score': 0.49427688121795654}]
#
# Tweet: best sale right youll look back price long wish bought aapl amzn blk dis hd jnj jpm ko msft trow v else
# Sentiment: [{'label': 'LABEL_2', 'score': 0.6612328290939331}]
#
# Tweet: amazon amzn announced kindle scribe first kindle write
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7708356380462646}]
#
# Tweet: amazon amzn link astro robot ring virtual security guard
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8481703996658325}]
#
# Tweet: amazon amzn unveils device track breathe sleeping
# Sentiment: [{'label': 'LABEL_1', 'score': 0.7562158107757568}]
#
# Tweet: found little green today amzn ttd nnox crwd aty sq mgni shop se meta zi abnb hope got piece sending prayer friend florida
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6005462408065796}]
#
# Tweet: amazon amzn encouraging customerservice worker u call center work home signaling preference remote work certain role would help save money real estate per bloomberg
# Sentiment: [{'label': 'LABEL_2', 'score': 0.7164011597633362}]
#
# Tweet: amazon raising hourly wage warehouse shipping worker amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6895773410797119}]
#
# Tweet: option trading watchlist amzn p lt twtr bearish job report impactful significant change monitoring usd strength yield well review flow via unusual whale optionstrading stock
# Sentiment: [{'label': 'LABEL_1', 'score': 0.821445643901825}]
#
# Tweet: news boe buy bond save pension mortgage rate advertiser leave twtr politician stock ban bill amzn new kindle ken griffin u recession b ulkraine eu cap ru oil nordstream sabotage future
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6363092064857483}]
#
# Tweet: stock think entering intriguing level add several im already overweight amzn goog axon celh z aapl hd ddog
# Sentiment: [{'label': 'LABEL_2', 'score': 0.5188908576965332}]
#
# Tweet: amazon loan small business next year bloomberg amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.849650502204895}]
#
# Tweet: wage inflation profit margin amzn
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8643375039100647}]
#
# Tweet: top qqq holding credit rating aapl aaa msft aaa amzn tsla ba goog aa googl aa meta nvda pep cost aa coming month investor learn credit rating important
# Sentiment: [{'label': 'LABEL_1', 'score': 0.8332664370536804}]
#
# Tweet: druckenmiller owned cvna year munger bought baba margin aswath dean valuation damodoran loved amzn meta year one safe investing loss wary anyone always right side every trade long list bird app
# Sentiment: [{'label': 'LABEL_1', 'score': 0.6137046217918396}]
#
# Tweet: today drop spx perfect example happens aapl amzn turn lower name held market year name finally dropping beginning see damage healthy market driven name
# Sentiment: [{'label': 'LABEL_0', 'score': 0.49245011806488037}]
#
# Tweet: nio im money doesnt mean bad investment whole market everything suck right year im confident pay long best aapl amzn tsla googl nio
# Sentiment: [{'label': 'LABEL_1', 'score': 0.4886617362499237}]
#
# Tweet: group lawmaker led sen elizabeth warren dmass asking federal trade commission reject amazon amzn proposed acquisition irobot per letter shared first axios
# Sentiment: [{'label': 'LABEL_1', 'score': 0.5515705943107605}]
# Embedding dimensions for the first tweet: (120, 768)

# %%
print("Some embeddings for the first tweet: ", embeddings[0][0, :5])  # Print the first 5 tokens of the first tweet
print("Dimensions of the embeddings ", embeddings.shape )
# Out:
# Some embeddings for the first tweet:  [-0.836834   -0.44356164  0.06713825 -0.5251011   0.38492772]
# Dimensions of the embeddings  (9145, 120, 768)

# %%
# dimensions of the tweet embeddings is (9145, 223, 768) tensor
# k-means requires 2D data, hence averaging the embeddings across tokens (the middle dimension) for each tweet
# Calculate the mean across the token dimension
embeddings_mean = embeddings.mean(axis=1)

print("Dimensions of the embeddings mean: ", embeddings_mean.shape)
# Now `tweet_embeddings_mean` has shape (9145, 768)

# Perform k-means clustering
kmeans = KMeans(n_clusters=2, random_state=0).fit(embeddings_mean)
labels = kmeans.labels_
print("Labels - ", labels)

# Print the cluster each tweet belongs to
for tweet, label in zip(tweets, labels):
    print(f"Tweet: {tweet} - Cluster: {label}")
    print("------------")
# Out:
# Dimensions of the embeddings mean:  (9145, 768)
# /Users/balubabu/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Labels -  [0 1 0 ... 0 0 1]
# Tweet: bought first aapl stock since seen increase tell dont invest - Cluster: 0
# ------------
# Tweet: medium really pushing hard big money client tsla option tomorrow sht make laughable even hitting new low anyone care sell stock year ago buffett sold aapl last year talk - Cluster: 1
# ------------
# Tweet: tim cook ceo aapl earned total compensation warren buffett earned dividend aapl zero hour clocked zero meeting amp zero headache caused invest - Cluster: 0
# ------------
# Tweet: thread broad overview balance sheet want specific amp helpful example deep dive balance sheet youtube channel using aapls recent number example - Cluster: 0
# ------------
# Tweet: trendline aapl continuing reject - Cluster: 0
# ------------
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx amazon amzn apple aapl sampp spy bond agg gold gld literally picked worst performing asset - Cluster: 1
# ------------
# Tweet: need share aapl - Cluster: 0
# ------------
# Tweet: trade plan friday spx fails p work spx hold open c work lotto amzn pull back tomorrow put work aapl hold bounce mon call work - Cluster: 1
# ------------
# Tweet: disclaimer high risk lottofriday keep bet small lock gain aapl c gt p lt afrm c gt p lt chwy c gt p lt mrna c gt p lt good luck - Cluster: 1
# ------------
# Tweet: eod leaderboard amc c qqq p uvxy c amc c ung c aapl p mrk c teva c full list - Cluster: 1
# ------------
# Tweet: september vol vix tesla tsla bond agg gold gld sampp spy amazon amzn na qqq apple aapl microsoft msft googl bitcoin btc ark innovation arkk facebook fb ethereum eth evergrande egrnf - Cluster: 1
# ------------
# Tweet: aapl monthly bearish engulfing nearing prior supply zone - Cluster: 0
# ------------
# Tweet: share aapl - Cluster: 0
# ------------
# Tweet: talking aapl customer service morning asked model iphone paused good second think thats cycle - Cluster: 0
# ------------
# Tweet: tech focused firm dominate top market cap tech company think make list aapl msft googl amzn fb tsla tsm tcehy - Cluster: 0
# ------------
# Tweet: aapl mentioned ticker wsb - Cluster: 0
# ------------
# Tweet: signing weekend friendly reminder q went long cmg ran amzn ran aapl august c shop ran nke august call ran nflx october call ran free amp join u q lfg - Cluster: 1
# ------------
# Tweet: result lottofriday aapl p afrm p chwy p mrna p mrna gapped gave u retest move cheer hagw - Cluster: 1
# ------------
# Tweet: woah aapl currently bullish darkpool playing link - Cluster: 0
# ------------
# Tweet: portfolio holding year tla tesla pltr palantir voo btc bitcoin b se sea ltd nvda nvidia vti eth ethereum c goog google upst upstart arkk doge dogecoin aapl apple sofi sofi qqq ada cardano - Cluster: 1
# ------------
# Tweet: look favorite dividend stock starbucks sbux price avg target upside apple aapl price avg target upside broadcom avgo price avg target upside - Cluster: 0
# ------------
# Tweet: current holding since ppl asked gogo ntnx pd twtr crm roku onds avpt fsly aapl estc wday plan orgn bark mu vwe watching pin bought sold poor action amd docn rebuy zm baba dis insg myov pton z wynn - Cluster: 1
# ------------
# Tweet: biggest challenge getting active manager bmd sampp tsla pe x fy street eps x aapl amzn googl msft fb good exercise est float active mgrs might buy full weight unlikely happen yet - Cluster: 1
# ------------
# Tweet: elite option watchlist shop c stop lulu c stop swing trade idea aapl c stop uber c stop - Cluster: 0
# ------------
# Tweet: aapl ema demand hammer bounce aapl gt amp im eyeing c amp uber flag breakout uber gt amp im eyeing oct c - Cluster: 0
# ------------
# Tweet: trouble deciding stock invest safe amp simple stock choose etf vanguard charles schwab voo schd qqq vti scha dsi growth goog amzn brka dividend aapl msft jnj wm - Cluster: 1
# ------------
# Tweet: gtsif team w wba fight mtbi amp pstd full reportdisclaimer amc nio bbby btc mrk ddtg wallstreetbets amc aapl tsla crm coin hood sbux lyft grub amzn rwlk adbe fsr plug lcid - Cluster: 1
# ------------
# Tweet: xclusivetriggers weekly fb call put aapl call put amzn call put nflx call put googl call put tsla call put roku call put zm call put - Cluster: 1
# ------------
# Tweet: largest dividend payer microsoft msft atampt exxon mobil xom apple aapl jp morgan jpm based amount dividend paid - Cluster: 1
# ------------
# Tweet: largest stock performed far today apple aapl microsoft msft google googl amazon amzn facebook fb tesla tsla taiwan semi tsm berkshire brkb nvidia nvda visa v jpm baba - Cluster: 1
# ------------
# Tweet: innovation amp growth sell aapl buy tsla public safety sell fb buy tsla total addressable market sell nflx buy tsla antitrust sell goog buy tsla valuation sell nvda buy tsla founderrun sell msft buy tsla cool factor sell amzn buy tsla - Cluster: 1
# ------------
# Tweet: apple stock fall correction territory alltime high aapl - Cluster: 0
# ------------
# Tweet: fb aapl amzn msft googl - Cluster: 0
# ------------
# Tweet: mentioned ticker wsb via swaggy stock fb wish tsla baba aapl pltr amzn qqq tlry nvda - Cluster: 1
# ------------
# Tweet: quality stock near aapl adbe amat apps crwd docu estc etsy fb meli pypl shop sq v yeti stock historically caught support built base near respective stock chart - Cluster: 1
# ------------
# Tweet: aapl daily falling wedge - Cluster: 0
# ------------
# Tweet: overthinking investing long term stock pick face iphone aapl netflix nflx twitter twtr amazon amzn mcdonalds mcd target tgt walmart wmt use invest know - Cluster: 1
# ------------
# Tweet: watch today marketoutlook video mentioned spy spx qqq iwm rut uup tnx tlt gld uso btc nflx rost tjx mrk aapl msft xlu xlre dbc nvda xlf xle bnd dvax - Cluster: 1
# ------------
# Tweet: mentioned ticker wsb via swaggy stock pltr sdc tsla wish fb tlry nflx aapl coin amzn - Cluster: 1
# ------------
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx domino dpz amazon amzn microsoft msft apple aapl google googl sampp spy bond agg gold gld - Cluster: 1
# ------------
# Tweet: warren buffetts top position aapl apple bac bank america axp american express ko coca cola khc kraft heinz currently much top position pay annual dividend aapl bac axp ko khc - Cluster: 1
# ------------
# Tweet: largest market cap trillion aapl msft goog amzn btc fb tsla - Cluster: 0
# ------------
# Tweet: day gm catch even get close tsla day nokia flip phone overtake aapl iphone - Cluster: 0
# ------------
# Tweet: retail capital flocked crypto bc last place theyre allowed make asymmetric upside investment one could buy msft aapl early amp see huge return public wait ipo first x already made private mkt - Cluster: 1
# ------------
# Tweet: sure exact timing fb unfettered access data eventually come end itll aapl want reignite revenue - Cluster: 0
# ------------
# Tweet: buy anything btc doge latest release get brand new aapl iphone bitplaza shopping app pay dogecoin bitcoin crypto doge cme - Cluster: 1
# ------------
# Tweet: blessed another amazing day day amp week far traded aapl msft snap ba - Cluster: 0
# ------------
# Tweet: buying shib like buying aapl steve job even born - Cluster: 0
# ------------
# Tweet: wont imagine much longer use anemoi terminal youll able ride elephant back almost ready go live amc fb amzn aapl nflx goog msft tsla - Cluster: 1
# ------------
# Tweet: aapl aapl ready repeat - Cluster: 0
# ------------
# Tweet: thats chart next day orlando tomorrow evening monday great rest week reviewed spy qqq iwm btc eth crm spot afrm penn aapl fubo net apps nflx dis upst snow sdc tsla - Cluster: 1
# ------------
# Tweet: exclusivedutch antitrust authority find apple inapp payment system anticompetitive source aapl - Cluster: 0
# ------------
# Tweet: aapl plan car using iphone control ac seat radio bloomberg - Cluster: 0
# ------------
# Tweet: confirmed earnings october aapl jpm tsm fb nflx snap clf bac dal sq pfe blk wfc wba intc googl f c dpz unh gm jnj nue cmc aa twtr ba qcom lrcx fyi amzn tsla amd baba msft scheduled earnings yet - Cluster: 1
# ------------
# Tweet: top dividend growth stock abbv aapl avgo sbux v hd low jpm msft cost - Cluster: 0
# ------------
# Tweet: friday lotto call idea break snap call break aapl call break snow call break tsla call - Cluster: 0
# ------------
# Tweet: hm could humanity survive alphabet googl completely shutdown eliminate following google map youtube search android seo cooky amp related apps might important company maybe aapl v thought - Cluster: 1
# ------------
# Tweet: lottofriday idea advised high risk xom c gt p lt pltr c gt p lt aapl c gt p lt qqq c gt p lt scale profit good luck like three extra pick - Cluster: 1
# ------------
# Tweet: delighted share conversation journey investor power digital business like aapl nflx course evo - Cluster: 0
# ------------
# Tweet: popular ticker search dot com thursday u treasury yield dow jones industrial avg tesla tsla sampp apple aapl algorand alibaba baba solana moderna mrna nasdaq composite - Cluster: 1
# ------------
# Tweet: lotto friday xclusivetriggers fb call put aapl call put amzn call put nflx call put googl call put tsla call put msft call put spy - Cluster: 1
# ------------
# Tweet: aapl reportedly building new regional headquarters los angeles - Cluster: 0
# ------------
# Tweet: let clear aapl never car never fact id bet never car project titan happening year going anything tsla - Cluster: 0
# ------------
# Tweet: update apple tesla nio qqq spy roku squarecash draftkings nvidia bitcoin xpeng etsy amd content tech qqq aapl msft nvda amd mu growth tsla nio etsy roku sq xpev nndm arkk reopening spy dkng xom dis jblu crypto btc eth - Cluster: 1
# ------------
# Tweet: jon youre smart guy favor spend minute modeling happens tsla rev ev adoption go current use whatever tsla ev share assumption want tsla rev pa aapl - Cluster: 1
# ------------
# Tweet: mentioned ticker wsb via swaggy stock clov sdc tsla baba wish pltr gme aapl tlry qqq - Cluster: 1
# ------------
# Tweet: mentioned ticker wsb via swaggy stock sdc tsla wish baba gme qqq amzn aapl nflx body note cei allowed wsb market cap billion current market cap million - Cluster: 1
# ------------
# Tweet: singlehandedly built one five industry changed world past year cellphone aapl search goog eretailing amzn social networking fb ev tsla one quibble timing vision second none - Cluster: 1
# ------------
# Tweet: mentioned ticker wsb via swaggy stock gme wish amzn fb aapl tsla nflx sdc dis qqq - Cluster: 1
# ------------
# Tweet: used waste money nike cocacola new iphones buy nke ko aapl investing change mindset - Cluster: 0
# ------------
# Tweet: stock amount profit last month saudi aramco b berkshire brkb b apple aapl b google googl b microsoft msft b - Cluster: 1
# ------------
# Tweet: 𝑴𝒂𝒓𝒌𝒆𝒕 𝑬𝒗𝒂𝒍𝒖𝒂𝒕𝒊𝒐𝒏 𝑻𝒓𝒂𝒅𝒆 𝑰𝒅𝒆𝒂𝒔 sq amd tsla nio roku zm snow aapl amzn googl msft spy 𝙂𝙇 share winner tagging show like rt share flow week - Cluster: 1
# ------------
# Tweet: xclusivetriggers fb call put aapl call put nflx call put tsla call put f call put amd call put also merch store live - Cluster: 1
# ------------
# Tweet: turned computer first time month weekend came last night aapl pro good know still got game con cardiac rehab workout morning missed whole thing - Cluster: 0
# ------------
# Tweet: im buy aapl share month - Cluster: 0
# ------------
# Tweet: dividend paying company whose product used daily jnj aapl msft xom vz sbux tgt pep nke mo - Cluster: 1
# ------------
# Tweet: apple ever hit per share id apple stock portfolio super bullish aapl amp aal american airline im aal investment since beginning pandemic - Cluster: 0
# ------------
# Tweet: apple say apple event scheduled oct pdt aapl - Cluster: 0
# ------------
# Tweet: aapl holding special event october - Cluster: 0
# ------------
# Tweet: apple aapl announced today hosting event october th starting pm est - Cluster: 0
# ------------
# Tweet: breaking new aapl event october announced could apple car tsla - Cluster: 0
# ------------
# Tweet: lcid aapl announced event right lucid stream - Cluster: 0
# ------------
# Tweet: aapl expected announce new macbooks airpods october event - Cluster: 0
# ------------
# Tweet: first deal streaming medium giant nflx spot aapl duke duchess sussex looking become investing royalty esg deal originally reported story - Cluster: 0
# ------------
# Tweet: think tsla idly sit aapl flirt creating electric car sorely mistaken believe tesla counter cell phone equivalent - Cluster: 0
# ------------
# Tweet: tsla different era story aapl disrupter come better tech big guy nokia motorola bb slow react finally figure abandon old tech late tsla short seriously underestimating impact ice brand taint - Cluster: 1
# ------------
# Tweet: aapl apple poised slash iphone production goal due chip crunch apple supplier broadcom ti struggling deliver enough chip - Cluster: 0
# ------------
# Tweet: tim cook supply chain expert aug th sold million worth aapl stock im big fan tim come - Cluster: 0
# ------------
# Tweet: aapl reportedly expects produce million fewer iphones initially planned chip shortage - Cluster: 0
# ------------
# Tweet: chip shortage due supply chain iphone lack demand last year pull forward minor upgrade iphone aapl - Cluster: 0
# ------------
# Tweet: find think weak close sampp may mean market next es_f spx ndx spy aapl tsla btc bitcoin fb es_f nq_f - Cluster: 1
# ------------
# Tweet: smart bloomberg drop aapl news close - Cluster: 0
# ------------
# Tweet: cnbc everything power brush aapl news pretty pathetic tsla news tire blew model driving today theyd talk safety nhtsa would involved consumer report would publish phil would air lora typing - Cluster: 1
# ------------
# Tweet: apple said slashing iphone production due semi chip shortage aapl - Cluster: 0
# ------------
# Tweet: would choose hold next year google googl bitcoin btc walmart wmt square sq b apple aapl tesla tsla berkshire brkb paypal pypl c microsoft msft ethereum eth disney dis draftkings dkng amazon amzn nvidia nvda jnj palantir pltr - Cluster: 1
# ------------
# Tweet: week got even interesting nites report apple cutting iphone production unit due chip shortage aapl cant source part due size get first dibs supplier tech mfrs worse shape widespread impact - Cluster: 0
# ------------
# Tweet: aapl stock never split would worth k rn imagine tsla year tesla bigger ecosystem apple energy software battery robot ai service car etc - Cluster: 0
# ------------
# Tweet: top analyst say tesla appleesque buy stock new tsla tesla apple aapl - Cluster: 0
# ------------
# Tweet: apple likely cut iphone production due chip crunch aapl - Cluster: 0
# ------------
# Tweet: report tuesday indicated apple could cut iphone production much million unit supply problem analyst dont believe itll affect apple much aapl - Cluster: 0
# ------------
# Tweet: cant stop wont stop spy c chwy c chwy c fb c dkng lulu mgm c aapl c calling teamalgonaut like mm - Cluster: 1
# ------------
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx domino dpz amazon amzn microsoft msft apple aapl google googl sampp spy bond agg gold gld - Cluster: 1
# ------------
# Tweet: watchlist tomorrow abbv ivc prog gmbl slgg amp aapl - Cluster: 0
# ------------
# Tweet: excellent minute discussion analysis massive list today e qqq aapl amd amzn afrm googl nvda fb dkng q nflx shop roku fdx snap fslr sq blnk spot watch please retweet share thanks - Cluster: 0
# ------------
# Tweet: ev inflection point tesla top mountain analyst new tsla tesla apple aapl - Cluster: 0
# ------------
# Tweet: today want make point paper portfolio look like today aapl amzn arkw goog tsla - Cluster: 0
# ------------
# Tweet: shanghai austin berlin enough tsla gt aapl revenue profit valuation - Cluster: 0
# ------------
# Tweet: incredible spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c play given live free twitter requesting - Cluster: 1
# ------------
# Tweet: spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c play given live free twitter okay - Cluster: 1
# ------------
# Tweet: dd guy want tonight ah retweet aapl like ba retweets count vote - Cluster: 0
# ------------
# Tweet: make life easier buy company lead respective industry aapl msft amzn sbux jnj mmm wait - Cluster: 0
# ------------
# Tweet: moon amp mar spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c ba c free goal - Cluster: 1
# ------------
# Tweet: patient investor rewarded amzn traded today amzn trade hd traded today hd trade aapl traded today aapl trade avgo traded today avgo trade - Cluster: 1
# ------------
# Tweet: blessed day amp week traded took uber swing called yesterday dkng nvda penn aapl chwy bbig ran back back day - Cluster: 0
# ------------
# Tweet: apple watch series arrives tomorrow biggest update larger display size last year price point declare aapl winner wrist significant growth potential ahead - Cluster: 0
# ------------
# Tweet: aapl aapl weekly candle looking good - Cluster: 0
# ------------
# Tweet: alright everyone thats tonight good one make sure check trade idea video today reviewed following chart feed spy roku tsla amd nvda nndm nio spot maxr penn dkng aapl plby fubo twtr - Cluster: 0
# ------------
# Tweet: watch today marketoutlook video mentioned spy spx qqq iwm rut uup tnx tlt gld uso btc xlre xlf xle xlv xly sgms swx iep crm mdb bill wba msft aapl c wfc blk bac etn emr xlk orcl - Cluster: 1
# ------------
# Tweet: aapl day higher report million phone production cut stock go bad news bullish signal - Cluster: 0
# ------------
# Tweet: numerous investor missed x return top growth stock bc waiting cheaper valuation however high quality growth stock tend stay expensive time amzn aapl nflx adbe nvda amd - Cluster: 1
# ------------
# Tweet: amazing week spy c chwy c chwy c fb c dkng lulu mgm c aapl c rblx c ba c scalp free goal smash - Cluster: 0
# ------------
# Tweet: look around usevisit find high quality dividend stock jnj aapl msft xom ko v nke sbux mcd - Cluster: 0
# ------------
# Tweet: astronomical week spy c chwy c fb c dkng lulu mgm c aapl c rblx c ba c scalp free like ba upside pt - Cluster: 1
# ------------
# Tweet: warren buffett berkshire hathaway brkb largest holding apple aapl b bank america bac b american express axp b cocacola ko b kraft heinz khc b moody mco b verizon vz b u bancorp usb b davita dva b chtr b - Cluster: 1
# ------------
# Tweet: hope chart helpful morning great saturday lot info weekend update spy start qqq iwm btc eth tsla nio aapl nvda amd penn - Cluster: 0
# ------------
# Tweet: portfolio holding year aapl apple pltr palantir arkg ada cardano b se sea ltd amzn amazon qqq eth ethereum c googl google upst upstart voo sol solana tsla tesla sofi sofi arkk btc bitcoin - Cluster: 1
# ------------
# Tweet: aapl weekly catching bid right demand zone - Cluster: 0
# ------------
# Tweet: got monthly substack newsletter sub giveaway likecommentretweet chance win must following spy spx aapl amzn googl tsla qqq snap nio pltr sq gme amc mst nflx fb roku - Cluster: 1
# ------------
# Tweet: new netflix movie theater palisade apple territory love nflx buying theater showing show movie add movie pa tier aapl - Cluster: 0
# ------------
# Tweet: glove im literally spending whatever take painfully large amount lawyer fee able actually kind open mouth engage founding father envisioned free speech amc gme bb fb aapl amzn goog msft - Cluster: 1
# ------------
# Tweet: spot aapl amzn - Cluster: 0
# ------------
# Tweet: chart pattern cheat sheet optionstrading spy aapl - Cluster: 0
# ------------
# Tweet: monday relatively quiet day growth stock well noteworthy aapl event googl event tost quiet period expiration riot investor tour - Cluster: 0
# ------------
# Tweet: weekly watchlist baba c gt p lt amd c gt p lt tsla c gt p lt xpev c gt p lt c gt p lt aapl c gt p lt unlock favorite swing setup - Cluster: 1
# ------------
# Tweet: public watchlist sq c coin c aapl c pton p baba p chart amp bonus pick posted later tonight good luck trader - Cluster: 0
# ------------
# Tweet: mentioned ticker wsb via swaggy stock tsla aapl amzn gme fb wish nflx upst sofi bb - Cluster: 1
# ------------
# Tweet: lts weekly watchlist solid week ton setup good luck everyone feel free reach question may aapl pypl fb sq spot shop googl tsla nvda amd amzn msft baba upst cat spy spx qqq - Cluster: 1
# ------------
# Tweet: panda weekly watchlist aapl c p msft c p sq c p amzn c coin c amd c - Cluster: 0
# ------------
# Tweet: opc top aapl gt supply sq gt downtrend break - Cluster: 0
# ------------
# Tweet: breaking apple supplier foxconn unveils ev including sedan suv bus foxconn plan begin mass production electric car u thailand talk possible location europe well chairman liu said earlier year aapl tsla - Cluster: 1
# ------------
# Tweet: another exciting week stonk market coming monday aapl event wednesday tsla earnings friday fsd beta go everyone plus existing tester - Cluster: 0
# ------------
# Tweet: analyst consistently get wrong proper comparison tsla v oems walking dead tsla v googl aapl amzn bidu rivn lcid bunch private working autonomous vehicle - Cluster: 1
# ------------
# Tweet: k portfolio tech aapl msft amd dividend xom mo spg growth tsla sq pltr index qqq dia spy consumer ko mcd cost safety gld slv tlt next cash hand opportunity arise dca would change comment - Cluster: 1
# ------------
# Tweet: build portfolio pay monthly dividend stock would cover every month mo low jnj ko sbux hd csco abbv mmm jpm aapl avgo - Cluster: 1
# ------------
# Tweet: dumped tdoc today lost patience take buy sq aapl - Cluster: 0
# ------------
# Tweet: maybe another color option innovation aapl - Cluster: 0
# ------------
# Tweet: year incredible growth aapl - Cluster: 0
# ------------
# Tweet: jim chanos tsla short thesis tsla trade x eps tsla valuation greater auto mnfrs combined one need value growth stock npv earnings two competitor list need incl aapl googl amzn bidu rivn av maker etc - Cluster: 1
# ------------
# Tweet: told aapl product changed color - Cluster: 0
# ------------
# Tweet: new rd generation apple aapl airpods start - Cluster: 0
# ------------
# Tweet: aapl apple unveils pro chip first pro chip designed mac also introducing new macbook pro airpods airpods spatial audio magnetic charging - Cluster: 0
# ------------
# Tweet: apple cult like following people continually upgrade airpods phone ipads macbooks best thing share company buy aapl - Cluster: 0
# ------------
# Tweet: aapl treat - Cluster: 0
# ------------
# Tweet: phase fb phase ad platform phase shopping payment platform phase arvr hardware platform phase metaverse app store basically fb becomes fb amzn aapl one company - Cluster: 1
# ------------
# Tweet: today hosted lastest product launch appleevent soon itll possible buy aapl anticipate event like one today might impact stock price get ready decentralized stock platform launching q - Cluster: 1
# ------------
# Tweet: apple think new color innovation aapl - Cluster: 0
# ------------
# Tweet: ok pro chip great ill buying new macbook soon need whole movie aapl - Cluster: 0
# ------------
# Tweet: today play amd c hit nio swing c hit coin c hit aapl c hit msft c hit - Cluster: 0
# ------------
# Tweet: three force supporting sampp helped susmitas superb aapl airpods presentation stock closed right dollar cinch background open es_f spx ndx spy es_f nq_f zc_f cl_f oott - Cluster: 1
# ------------
# Tweet: new mac book look great apple great lineup product going holiday season expect record revenue profit although innovation evolution product great aapl - Cluster: 0
# ------------
# Tweet: aapl long hold new high axpected - Cluster: 0
# ------------
# Tweet: update apple tesla amazon nvidia spy qqq amd disney amc micron bitcoin ethereum content technology aapl amzn amd nvda msft tsla enph mu intc reopening inflation dis amc uuuu cper vale crypto btc eth mara riot mstr - Cluster: 1
# ------------
# Tweet: doubled pltr investment currently holding k worth truly believe one many trillion dollar company next decade good luck always dd good luck pltr nio tsla aapl coin tdoc fubo - Cluster: 0
# ------------
# Tweet: great collaboration amp analysis e qqq aapl amd amzn ba bidu mrna msft nflx nio fb roku shop snap snow cat bynd tsla please retweet find useful - Cluster: 1
# ------------
# Tweet: apple aapl luca maestro bond king gentleman know sell bond - Cluster: 0
# ------------
# Tweet: top stock purchased congress ice msft amzn nflx crm pypl aapl usac amza nvda link - Cluster: 0
# ------------
# Tweet: tgt say doubling number aapl shop store - Cluster: 0
# ------------
# Tweet: top stock member congress aapl msft boa dis pfe pfizer hmm jnj ge xom goog - Cluster: 0
# ------------
# Tweet: friendly reminder aapl largest public company world projecting sell airpods lose one every month tim apple win - Cluster: 0
# ------------
# Tweet: traded wife mac air new macbook impressive machine cant wait test apple great line holiday long aapl forever - Cluster: 0
# ------------
# Tweet: daily recap monster day cost c holding upst p pin c zm c quick scalp aapl c twtr c mrvl mat swing holding follow flow get bag - Cluster: 1
# ------------
# Tweet: another big day winner baba swing lrcx swing aapl rf baba rf snap rf loss ba sfbeta zm swing ccl x today overall slow day stayed patient amp fluid today trading desk view - Cluster: 1
# ------------
# Tweet: officially greed territory fb aapl amzn googl msft - Cluster: 0
# ------------
# Tweet: guy long aapl short fb evil always win - Cluster: 0
# ------------
# Tweet: watch today marketoutlook video mentioned spy spx qqq iwm rut uup tnx tlt gld uso btc gbtc bito btf bitcoin ul aapl ulta nflx tsla el dividendaristocrats pg jnj clx kmb - Cluster: 1
# ------------
# Tweet: lot strong setup posted tonight see tomorrow reviewed penn blnk maxr grwg fubo pton wish fslr acb ddd spot spy iwm fsly aapl mj - Cluster: 1
# ------------
# Tweet: wonderful discussion amp analysis e qqq baba aapl amd amzn ba bidu mrna msft nflx nio fb roku shop snap snow cat bynd tsla dis please like retweet find useful - Cluster: 1
# ------------
# Tweet: new wednesday post alert megacap tech stock make break market earnings loom fb report oct msft report oct googl report oct aapl report oct amzn report oct - Cluster: 1
# ------------
# Tweet: maga custom index msft aapl googl amzn new demark sequential sell countdown previous two time saw shortly signal - Cluster: 0
# ------------
# Tweet: return last year bitcoin btc tesla tsla nvidia nvda netflix nflx domino dpz amazon amzn microsoft msft apple aapl google googl sampp spy bond agg gold gld - Cluster: 1
# ------------
# Tweet: aapl flow highly bullish whale adding c - Cluster: 0
# ------------
# Tweet: strong dividend stock sbux hd v jnj abbv mmm aapl rtx ko - Cluster: 0
# ------------
# Tweet: watchlist tomorrow aapl mrk pin cxdc iht - Cluster: 0
# ------------
# Tweet: asked year old son give company like explaining company picked tsla aapl rblx year old better investor - Cluster: 0
# ------------
# Tweet: research think pypl move attempting acquire pin defense afrm pypl must felt serious threat afrm partnering w shop wmt amzn tgt hd pton aapl ssnlf etc long list afrm gon na blowout er - Cluster: 1
# ------------
# Tweet: aapl ad fb ad - Cluster: 0
# ------------
# Tweet: considering selling aapl share nio amp tsla - Cluster: 0
# ------------
# Tweet: b net profit apple aapl still cant make fucking battery worth shit - Cluster: 0
# ------------
# Tweet: q dividend rest year big name like xom vz aapl sbux spg intc jnj pfe wba nly bp - Cluster: 1
# ------------
# Tweet: isnt bad much trading go congress ramification take senator james inhofe briefed devastation covid jan sold k ie bam c dhr intu aapl pypl doj investigated nothing happened - Cluster: 1
# ------------
# Tweet: tsla bull case stock talk tesla q demand v supply constraint amp new gigafactories berlin amp austin plus fb rebrand aapl airpods amp msft earnings preview - Cluster: 1
# ------------
# Tweet: dont give fuck jay buy aapl call put - Cluster: 0
# ------------
# Tweet: say sampp brand getting profile fueled hbar face melt hbar hold tsla aapl msft amzn dis - Cluster: 0
# ------------
# Tweet: analysis year ago aapl change adtech ecosystem updating premium sub think might happen rest er quarter tell snap wont one affected simply first report - Cluster: 1
# ------------
# Tweet: nfl reportedly likely make sunday ticket deal either aapl amzn - Cluster: 0
# ------------
# Tweet: nq_f target amp es_f rty_f ym_f tech lead based nq_f one buy spy amp qqq humble warning lowerside limited time frame wil revealed depending amp rt nqestslaamznaapl - Cluster: 1
# ------------
# Tweet: total time reach billion market cap tsla year month goog year month amzn year month aapl year month msft year month - Cluster: 0
# ------------
# Tweet: big cap tech hurt snap revelation apple hurting ad business protecting privacy mean fb goog amzn issue especially facebook aapl - Cluster: 0
# ------------
# Tweet: cant invest right yet ate every day week cant invest right yet purchase latest aapl iphone every year cant invest right yet bought new car cant invest right yet ran huge bar tab - Cluster: 1
# ------------
# Tweet: top ten global market cap usd cryptos combined apple aapl microsoft msft saudi aramco alphabet goog amazon amzn bitcoin facebook fb b tesla tsla b berkshire hathaway brka b included gold - Cluster: 1
# ------------
# Tweet: roku aapl snap googl take everyone else idfa change still u tripled ad biz mo take basically bc seems legit - Cluster: 0
# ------------
# Tweet: scrolling feed idea dwac never heard trade aapl today min enjoy ur weekend - Cluster: 0
# ------------
# Tweet: xclusivetriggers apply trading week fb aapl nflx tsla amzn snap se mstr gain totaling combined - Cluster: 0
# ------------
# Tweet: hope everyone nice friday night new weekend update timestamps spy start qqq iwm btc eth solana tsla aapl roku sq amd atvi - Cluster: 0
# ------------
# Tweet: next week earnings going fun monday fb tuesday msft googl twtr amd wednesday twlo ba tdoc f algn thursday aapl amzn shop team many others - Cluster: 0
# ------------
# Tweet: upcoming earnings report week october th xom abev aapl sbux mrk cat avt asx bud amzn ebay gm ko mcd f ba db bmy bg amd ge googl twtr ups goog msft fb spy qqq free week benzinga pro - Cluster: 1
# ------------
# Tweet: year price increase soon appear well tsla gt aapl revenue tsla gt aapl margin tsla gt aapl cash flow tsla gt aapl valuation - Cluster: 1
# ------------
# Tweet: preparing present aapl conference - Cluster: 0
# ------------
# Tweet: go massive earnings week fb ups ge goog v twtr hood amd lly q rtx ba gm ko mcd spot teva twlo f algn upwk ebay tdoc shop cat aapl amzn sbux ostk xom abbv mstr name week - Cluster: 1
# ------------
# Tweet: fb shareholder hope multiple rerate higher better keep expectation low year mr market valued aapl almost like dying business hard imagine may inflict fb long time period aapl fcf cagr fb fcf cagr - Cluster: 1
# ------------
# Tweet: aapl fb googl snap - Cluster: 0
# ------------
# Tweet: big week tech earnings ahead mon fb tues msft googl amd twtr hood v wed ba mcd ko gm f thurs aapl amzn shop sbux cat fri xom cvx rcl dia spy qqq iwm vix - Cluster: 1
# ------------
# Tweet: next week huge week tech er season im focused lc atom im also watch broad market impact fb amd enph googl msft aapl twlo amzn shop team - Cluster: 1
# ------------
# Tweet: best dividenddividend growth stock money buy pep hd ko msft mmm aapl jpm pg jnj mcd spg cost v vz sbux nke xom mo wmt bac intc pfe wba irm add watchlist research build true passive income - Cluster: 1
# ------------
# Tweet: largest stock performed far apple aapl microsoft msft google googl amazon amzn facebook fb tesla tsla berkshire brkb nvidia nvda taiwan semi tsm jpmorgan jpm alibaba baba visa v - Cluster: 1
# ------------
# Tweet: aapl might easiest er run play trade idea aapl c premium open lower - Cluster: 0
# ------------
# Tweet: enjoy writing market enjoy reading market subscribe blog dwac mara coin aapl snap fb cost tsla goog bitcoin twtr tic top - Cluster: 0
# ------------
# Tweet: big earnings week ahead name like amd aapl amzn shop twtr v fb reporting guy watching - Cluster: 0
# ------------
# Tweet: public weekly watchlist aapl c atvi c fdx c jpm c nvda c chart bonus pick uploaded later tonight good luck trader - Cluster: 0
# ------------
# Tweet: week notable earnings via mon fb kmb tzoo tues msft googl amd twtr hood v txn ups ge mmm lmt wed ba mcd ko gm f spot tdoc ebay twlo upwk thurs aapl amzn shop sbux cat mo mstr x fri xom cvx rcl abbv cl - Cluster: 1
# ------------
# Tweet: quick update thread first tweet million impression twitter promoted tweet wouldve cost k day look earnings goog aapl etc imagine much press afford - Cluster: 0
# ------------
# Tweet: nio tsla aapl fortune stored cryptos fun company real tangible product line ive accumulating aapl year holding tsla since march nio month - Cluster: 0
# ------------
# Tweet: market evaluation 𝑻𝒓𝒂𝒅𝒆 𝑰𝒅𝒆𝒂𝒔 sq amd tsla nio roku zm snow aapl amzn googl msft spy 𝗚𝗼𝗼𝗱 𝗟𝘂𝗰𝗸 share trade tagging amp letting share flow show like rt enjoy - Cluster: 1
# ------------
# Tweet: aapl put - Cluster: 0
# ------------
# Tweet: q earnings kick full swing week aapl msft amzn googl fb twtr reporting biggest focus whether weak snap guidance last week following aapl io privacy change oneoff advertiser cutting back social medium advertising - Cluster: 1
# ------------
# Tweet: dividend stock come shape size low yieldhigher growth aapl msft v hd de moderate yield ko pep mmm jnj higher yield abbv xom cvx vz reit stor irm psa amt type invest - Cluster: 1
# ------------
# Tweet: long took asset reach market cap milestone bitcoin btc year tesla tsla year google googl year amazon amzn year apple aapl year microsoft msft year - Cluster: 1
# ------------
# Tweet: get new aapl apple watch series bitplaza app pay btc doge ltc based usa international shipping friendly customer support bitcoin dogecoin litecoin accepted crypto dogearmy litecoinfam - Cluster: 1
# ------------
# Tweet: tsla crossing today amp fb falling faang renamed gambat qe forever world new bogey googl aapl msft btc amzn tsla cc - Cluster: 1
# ------------
# Tweet: market capitalization feel justifiable given macro environment aapl msft goog amzn tsla bitcoin - Cluster: 0
# ------------
# Tweet: apple likely face doj antitrust suit information aapl - Cluster: 0
# ------------
# Tweet: aapl reportedly likely face antitrust suit department justice - Cluster: 0
# ------------
# Tweet: flash back stock trend several name headlining news today gain since fb tsla googl aapl nvda original blog - Cluster: 0
# ------------
# Tweet: stock think perfect small account stock option cheap premium volume tight bid ask spread aapl snap xpev lcid snap spy dis nio aal - Cluster: 0
# ------------
# Tweet: apple likely face doj antitrust suit information aapl - Cluster: 0
# ------------
# Tweet: aapl max beat amd radeon pro wx affinity benchmark test - Cluster: 0
# ------------
# Tweet: earn monthly dividend income stock mo low hd ko sbux msft stor aapl mmm csco pg avgo - Cluster: 1
# ------------
# Tweet: apple delaying new macbook pro preorders warning device wouldnt arrive today appleinsider aapl - Cluster: 0
# ------------
# Tweet: aapl granted patent smartglasses vr headset use direct retinal projector system - Cluster: 0
# ------------
# Tweet: last year uranium urnm coal arch ag mo oil xop copper teck metal xme sampp equal weight apple aapl facebook fb amazon amzn bond tlt equalweight gt big tech via - Cluster: 1
# ------------
# Tweet: getting ready aapl thursday night bottom line think investor going look past supply chain issue focus sustained step demand thanks accelerating digital transformation - Cluster: 0
# ------------
# Tweet: amzn gt msft gt aapl gt goog gtgtgtgtgtgtgtgtgt fb - Cluster: 0
# ------------
# Tweet: im sick amp tired people fintwit misleading retail trader isnt game semblance responsibility spent morning arguing amc could worth aapl amp googl said pricetarget realistic logical - Cluster: 0
# ------------
# Tweet: remember titan msft aapl googl amzn tsla - Cluster: 0
# ------------
# Tweet: announce fiscal result fourth quarter oct likely break quarterly record expect aapl - Cluster: 0
# ------------
# Tweet: pelosi democrat close agreement topline biden bill update aapl position earnings - Cluster: 0
# ------------
# Tweet: still shit coin dont sweat millionaire retrospectively tesla stock amazon aapl pre split cry million going get anywhere good luck bud fake - Cluster: 0
# ------------
# Tweet: word street people selling high risk meme stock aapl amp amzn buy low risk blue chip crypto called shib - Cluster: 0
# ------------
# Tweet: january posted conviction ranking stock portfolio top order w ytd return msft amzn tsla aapl nvda crwd represent portfolio good name keep winning focus - Cluster: 0
# ------------
# Tweet: guarantee msft googl amp qqq september high likely aapl lulling u sleep turn rotation aapl ended wave correction retracement wave aapl gt wave target - Cluster: 1
# ------------
# Tweet: qqq daily shooting star making aths double topping aapl amzn decide taking number earnings use imagination well get reversal confirmation - Cluster: 0
# ------------
# Tweet: stock hold year ko aapl - Cluster: 0
# ------------
# Tweet: market cap club member performed since aapl msft googl amzn tsla fb - Cluster: 0
# ------------
# Tweet: mimi greatest investor ill probably ever know put ira goog aapl rest spy brkb since passed kid pulled half starting value balance today x maybe lesson ngaf risktaking - Cluster: 1
# ------------
# Tweet: trailing year cagr msft aapl - Cluster: 0
# ------------
# Tweet: ccxi wm f c ivc tsla wmt cv rdib astr shop otrk lcid wtrh sxtc bynd spce aapl - Cluster: 1
# ------------
# Tweet: msft may overtake aapl valuable company world week microsoft le away apple - Cluster: 0
# ------------
# Tweet: huge club day amzn aapl stay close - Cluster: 0
# ------------
# Tweet: year btc year tsla year aapl taught important thing large return come time market accumulate quality asset recognized world fud near term fundamental outweigh long term - Cluster: 0
# ------------
# Tweet: aapl cloth - Cluster: 0
# ------------
# Tweet: usa gdp slowed data point remains unknown afaic aapl eps key level may decide next whether hold point sampp upon close tsla aapl sampp - Cluster: 1
# ------------
# Tweet: icymi mkt call amp discussed setup broad market big tech msft googl amzn aapl tesla tsla rally amp car htzz plus classic comedy cbw end sponsored amp - Cluster: 1
# ------------
# Tweet: googl aapl msft mvrs amzn - Cluster: 0
# ------------
# Tweet: hearing cathie wood bought million kopn share cheap stock lowest year specializes manufacturing wearable tech could relate fb vr aapl earnings stock double near future share must - Cluster: 1
# ------------
# Tweet: daily recap lcid nov cc banked k weekly sq c aapl c mrna c morning call snap full day reload c rblx c nov quick holding like retweets open discord nov - Cluster: 1
# ------------
# Tweet: miss coming aapl amzn market finally correct little sometimes market opposite - Cluster: 0
# ------------
# Tweet: earnings apple q eps v est q rev b v b est aapl - Cluster: 0
# ------------
# Tweet: apple aapl report q earnings billion revenue estimate - Cluster: 0
# ------------
# Tweet: apple q rev b est b apple q iphone revenue b est b aapl - Cluster: 0
# ------------
# Tweet: think safely say snap wasnt reporting company specific issue reporting economy wide issue aapl amzn fb twtr shop would agree - Cluster: 0
# ------------
# Tweet: aapl ceo say supply constraint affecting line apple product - Cluster: 0
# ------------
# Tweet: aapl amzn miss badly time everyone go back safer stock like biotech xbi - Cluster: 0
# ------------
# Tweet: aapl sale product line - Cluster: 0
# ------------
# Tweet: one megacap another miss est get trashed tsla googl stand tall many pm buying tsla told cant find anything else buy megacaps aapl amzn msft googl tsla fb rg benchmark supply constraint didnt impact tsla q - Cluster: 1
# ------------
# Tweet: apple q sale miss weak q outlook amazon q revenue miss disappointing q guidance nasdaq future aapl amzn - Cluster: 0
# ------------
# Tweet: aapl amzn reset market overbought condition money follow strong name eg googl amd amp tsla like lcid gim tomorrow - Cluster: 0
# ------------
# Tweet: aapls net cash drop another bn bn time high bn dec back level last seen decade ago - Cluster: 0
# ------------
# Tweet: big day printing win aapl rf x spce x lcid rf fb rf shop loss pypl sfbeta futu rf swing x xom aapl small er lotto today overall stayed fluid amp banked - Cluster: 1
# ------------
# Tweet: aapl amzn - Cluster: 0
# ------------
# Tweet: aapl hour amzn hour - Cluster: 0
# ------------
# Tweet: aapl amzn market sentiment depending react market likely go tomorrow - Cluster: 0
# ------------
# Tweet: amzn aapl shitting bed look like fate global equity market rest solely biggest fraud history tsla - Cluster: 0
# ------------
# Tweet: aapl amzn money tsla - Cluster: 0
# ------------
# Tweet: apple revenue billion est aapl - Cluster: 0
# ------------
# Tweet: aapl apple fy q eps 売上高bb highlight iphone bb mac bb ipad bb wearable home accessory bb service bb 時間外 - Cluster: 1
# ------------
# Tweet: ignored everyone around getting iphone aapl ignored often used amzn ignored disruptive tsla could ignored people trying convince bitcoin wont ignoring disruptive nfts - Cluster: 0
# ------------
# Tweet: big tech successful set expectation high think amzn making b aapl making b last quarter bad quarter - Cluster: 0
# ------------
# Tweet: fb meta reportedly developing smart watch direct competitor aapl watch - Cluster: 0
# ------------
# Tweet: aapl say expect record revenue q - Cluster: 0
# ------------
# Tweet: q revenue growth yoy change tesla tsla google googl facebook fb apple aapl microsoft msft netflix nflx amazon amzn sampp spy - Cluster: 1
# ------------
# Tweet: combined revenue largest u company hit record trillion last month apple aapl billion microsoft msft billion google googl billion amazon amzn billion thats larger gdp country - Cluster: 0
# ------------
# Tweet: seen wsb pretty sure next step aapl bankruptcy - Cluster: 0
# ------------
# Tweet: wont take nio long reach trillion market capitalization took tsla year took goog year took amzn year took aapl year took msft year nio giantinthemaking - Cluster: 1
# ------------
# Tweet: supply chain issue crashed iphone party quarter overhang december quarter view transitory way impact long term bullish view aapl heading trillion market cap demand gt supply apple - Cluster: 1
# ------------
# Tweet: tsla equity fell ndx weak q guide aapl amzn higher yr ty bp ecbs lagarde gave mild pushback higher int rate k ev credit dems infrastr bill tsla option expiring today volatility - Cluster: 1
# ------------
# Tweet: aapl morgan stanley see thing important supply chain issue service growth surprised positively remains yy dec q gross margin guidance commentary implies december revenue inline consensus despite gtb supply shortfall - Cluster: 1
# ------------
# Tweet: msft overtaken aapl valuable company world - Cluster: 0
# ------------
# Tweet: apple aapl currently set open today trading world nd largest company behind microsoft msft - Cluster: 0
# ------------
# Tweet: aapl price target raised oppenheimer - Cluster: 0
# ------------
# Tweet: microsoft set surpass apple valuable u company market cap trillion msft aapl - Cluster: 0
# ------------
# Tweet: microsoft msft largest public company world ahead apple aapl source - Cluster: 0
# ------------
# Tweet: student wait buy nq_f every day open pretty much student aapl amzn like yeah doesnt matter - Cluster: 0
# ------------
# Tweet: look pull back add name like apple one like great report xmas season ahead apple break record qtr aapl - Cluster: 0
# ------------
# Tweet: gm everyone long aapl amzn - Cluster: 0
# ------------
# Tweet: microsoft worth apple aapl msft - Cluster: 0
# ------------
# Tweet: world valuable stock microsoft msft overtake apple aapl bloomberg - Cluster: 0
# ------------
# Tweet: people selling amzn aapl today loss buy tsla msft aths thats kinda mkt - Cluster: 0
# ------------
# Tweet: aapl amzn almost yet qqq spy almost green next week interesting great weekend everyone - Cluster: 0
# ------------
# Tweet: aapl amzn today nasdaq tell lot underlying strengthen market - Cluster: 0
# ------------
# Tweet: aapl billion dollar sale every day roughly equal entire stock market cap - Cluster: 0
# ------------
# Tweet: aapl sign top ever saw one - Cluster: 0
# ------------
# Tweet: october cloudflare net ethereum eth tesla tsla bitcoin btc solana sol coinbase coin msft googl oil na qqq sampp spy aapl amzn fb evergrande egrnf snap snap vol vix - Cluster: 1
# ------------
# Tweet: showoff day gwth stock even aapl amp amzn missed er estimate amp got sold new aths lc bros inmd net enph ampl oprx tsla team ddog z nvda msft next week historically best performing week amp many sm gwth stock release er gl - Cluster: 1
# ------------
# Tweet: told january q gdp would q likely negative amzn amp aapl would miss amp guide lower stimulus yield curve inverting fed going begin taper week would never bought spx - Cluster: 1
# ------------
# Tweet: monster day many banger today win amzn xom x rf lcid rf nvda rf spce sfb tsla jks sfb aapl n loss aapl swing twlo mara fisv rf overall stay fluid friend - Cluster: 1
# ------------
# Tweet: update apple tesla nio palantir amd sampp nasdaq airline draftkings bitcoin ethereum tech aapl msft nvda amd qqq spy clean energy explodes tsla nio fslr enph plug xpev fuv software amp crypto pltr fsly twlo btc eth xrp - Cluster: 1
# ------------
# Tweet: aapl resurgence started w peg fb ipo base break peg amp tsla insane run started w peg study new investor scared buy gap bc think missed thats usually start big move - Cluster: 1
# ------------
# Tweet: msft aapl combined currently worth x bitcoin fiat term early - Cluster: 0
# ------------
# Tweet: stock holding year wm dlr hd aapl amzn - Cluster: 0
# ------------
# Tweet: want stock metaverse u dis aapl fb rblx mttr nvda amd tsm asml - Cluster: 0
# ------------
# Tweet: portfolio would choose hold next year affirm afrm bitcoin btc palantir pltr twitter twtr b celcius celh tesla tsla square sq snap snap c apple aapl spotify spot redfin rdfn shiba inu shib upstart upst ethereum eth sea ltd se betz - Cluster: 1
# ------------
# Tweet: metaverse etf game u rblx ilv wild atlas axies aury naka coin eth matic dot link atom sol ray vr meta snap dis nvda aapl mttr land sand mana blok realm market coin meta rh dis gme chip nvda amd tsm asml miss - Cluster: 1
# ------------
# Tweet: move apple microsoft world valuable company msft aapl - Cluster: 0
# ------------
# Tweet: oct highlight lulu gt amd c gt sq c gt docu c gt pypl c gt snow c rblx c mgm c gt aapl c gt play given live free twtr - Cluster: 1
# ------------
# Tweet: biggest obstacle gain oct gain x street eps v x pe underwt pm keep hoping pullback long tsla est keep rising amznaaplfb est keep falling money motion instit pm likely buy dip - Cluster: 1
# ------------
# Tweet: warren buffett mentioned greatest investor time look top holding brkb portfolio aapl portfolio bac portfolio axp portfolio ko portfolio top position make total portfolio - Cluster: 0
# ------------
# Tweet: apple leading metaverse company right buy crypto look nfts iphone aapl - Cluster: 0
# ------------
# Tweet: aapl monthly prior resistance new support - Cluster: 0
# ------------
# Tweet: aapl mixed reality device could launch soon next year - Cluster: 0
# ------------
# Tweet: public weekly watchlist coin c spot c bac c aapl c mrna p good luck trader - Cluster: 0
# ------------
# Tweet: market evaluation 𝑻𝒓𝒂𝒅𝒆 𝑰𝒅𝒆𝒂𝒔 sq amd tsla nio roku zm snow aapl amzn googl msft spy qqq 𝗚𝗼𝗼𝗱 𝗟𝘂𝗰𝗸 thanks letting share flow share trade taggingamp show likert please help lot - Cluster: 1
# ------------
# Tweet: aapl call average price stop loss day trade - Cluster: 0
# ------------
# Tweet: aapl flow update putcall ratio call premium million k k k targeting expiry strike dark pool link - Cluster: 0
# ------------
# Tweet: apple plan iphone feature detect car accident autodial source say aapl - Cluster: 0
# ------------
# Tweet: aapl apple cofounder steve wozniak say cant tell difference iphone - Cluster: 0
# ------------
# Tweet: money flowing amzn goog amp aapl right tsla - Cluster: 0
# ------------
# ...
# ------------
# Tweet: normalize difference company really better use peg ratio pe divided eps growth estimate measure tsla amzn suddenly look relatively cheap - Cluster: 0
# ------------
# Tweet: amazon keep price artificially high california suit say amzn - Cluster: 0
# ------------
# Tweet: california sue amazon amzn antitrust law saying keep price artificially high - Cluster: 0
# ------------
# Tweet: free option idea scale profit aapl cgt plt nio cgt plt amzn cgt plt twtr cgt plt use ibkr fully automate order see super bonus pick - Cluster: 1
# ------------
# Tweet: trade plan thursday spx consolidated closed near spx reclaim set move tsla need test call work amzn setting hold call work - Cluster: 1
# ------------
# Tweet: news amzn sued mortgage cramer bear market russia x china amtrack longtrains cancelled eth emrge pelosi stock ban incoming patagonia founder donates company taiwan bill pa senate committee future - Cluster: 1
# ------------
# Tweet: k amzn today account crossed k today post trade breakdown later - Cluster: 0
# ------------
# Tweet: top shorted stock world value apple aapl tesla tsla microsoft msft google googl goog amazon amzn visa v mmm alibaba baba occidental petro oxy facebook meta total short interest list gt billion usd - Cluster: 1
# ------------
# Tweet: today note added several new sized short position amzn googl doubling aapl spy qqq short max size - Cluster: 0
# ------------
# Tweet: intro today marketoutlook video watch full video free mentioned spy spx qqq iwm rut tlt tnx bndx hyg eem efa uup pff aapl dkng stor adbe wynn fdx hum lvs amzn jpm cmcsa trow - Cluster: 1
# ------------
# Tweet: free option idea scale profit mrna cgt plt rblx cgt plt meta cgt plt amzn cgt plt use ibkr fully automate order see want secret stash - Cluster: 1
# ------------
# Tweet: googl breaking june low best sign probably needed gut tell lot nervous bull trying hide old faang name aapl amp amzn two havent gotten clobberedstay tuned - Cluster: 1
# ------------
# Tweet: dont think fdx problem macro think big portion amzn logistics arm taking big share - Cluster: 0
# ------------
# Tweet: european central bank selects amazon amzn develop digital euro epayments system - Cluster: 0
# ------------
# Tweet: jeff bezos amazon amzn lost spot world secondrichest person indian billionaire gautam adani per bloomberg - Cluster: 0
# ------------
# Tweet: spy put alerted last week gave return try give five free alert next two week lowcost premium expecting give retweets want free play let go spy qqq aapl amzn tsla meta baba googl msft amd - Cluster: 1
# ------------
# Tweet: good authority red tomorrow unfortunately thats today single green position crwd amzn shop se sq abnb apps mgni sofi upst lmnd date night pour concrete tomorrow hagw - Cluster: 1
# ------------
# Tweet: spy qqq tsla amzn aapl nvda arkk signing day start september smash like button loved setup enjoy weekend everyone - Cluster: 0
# ------------
# Tweet: cbdc getting closer reality amzn race gtgt ecb tap amazon four others pitch digital euro prototype - Cluster: 0
# ------------
# Tweet: amzn market cap profit b profit date b projected b projection b tsla market cap b profit b profit date b projected b projection b anyone see problem - Cluster: 1
# ------------
# Tweet: largest stock performed past week apple aapl microsoft msft google googl amazon amzn tesla tsla berkshire brkb unitedhealth unh jnj visa v facebook meta exxon xom tsm wmt - Cluster: 1
# ------------
# Tweet: performace largest stock since went public msft microsoft amzn amazon aapl apple googl google - Cluster: 0
# ------------
# Tweet: invested ipo would msft microsoft gt million amzn amazon gt million aapl apple gt million googl google gt - Cluster: 1
# ------------
# Tweet: since adopted bitcoin standard mstr btc goog aapl orcl msft sampp ibm nasdaq gold bond amzn crm silver meta sap nflx - Cluster: 1
# ------------
# Tweet: amzn generates operating profit aws - Cluster: 0
# ------------
# Tweet: top holding amzn msft v appl jnj sbux working bring schd top allocation hopefully december whats top holding - Cluster: 0
# ------------
# Tweet: share u tv time streaming cable broadcast including gaming streaming breakdown total netflix nflx youtube goog hulu prime video amzn disney dis streaming - Cluster: 1
# ------------
# Tweet: estimated bloomberg week post cpi jeff bezoss amzn lost billion elon musk lost billion fortune mark zuckerberg larry page sergey brin steve ballmer declined billion warren buffett lost billion - Cluster: 1
# ------------
# Tweet: top shorted sampp stock apple aapl tesla tsla microsoft msft google googl goog amazon amzn visa v mmm alibaba baba occidental petro oxy facebook meta - Cluster: 1
# ------------
# Tweet: amzn amzn new one never seen many volume gap - Cluster: 0
# ------------
# Tweet: ready check option play morning retweets ready let go spy qqq aapl amzn tsla meta baba googl msft amd - Cluster: 1
# ------------
# Tweet: since microstrategy adopted bitcoin standard mstr btc goog aapl orcl msft sp ibm nasdaq gold bond amzn crm silver meta sap nflx source - Cluster: 1
# ------------
# Tweet: big week ahead thanks checking stickynote amd let stay lane shorted key level nflx wow looking strong buy dip amzn bad week look awful msft week low - Cluster: 0
# ------------
# Tweet: amzn still position growth high coming year aws ad business logistics service business two segment still early inning amzn long amzn - Cluster: 0
# ------------
# Tweet: return twtr tsla aapl gme amzn msft goog team crm snow amd adbe pypl etsy mrna nvda meta spot zm sq nflx snap shop - Cluster: 1
# ------------
# Tweet: return twtr tsla aapl amzn msft goog crm meta spot zm sq nflx snap shop mike tyson nft could seen coming - Cluster: 1
# ------------
# Tweet: amazon remove solar april june solar panel atop amzn fulfillment center caught fireexploded least different time fire caused undetermined electrical event roofmounted solar system - Cluster: 0
# ------------
# Tweet: many following post hope worth time energy sharing input thank spy qqq amzn meta tsla baba googl nvda amd sq snow - Cluster: 0
# ------------
# Tweet: amazon say prime signups topped cyber monday nfl game amzn - Cluster: 0
# ------------
# Tweet: thanks looking today stickynote low volume day ahead tomorrow patience f b unexpected cost good whats next pypl downgrade plus heading towards amd patience pay long amzn msft - Cluster: 0
# ------------
# Tweet: sell tech stock goog aapl amzn - Cluster: 0
# ------------
# Tweet: ytd return amzn msft goog crm isrg wix idxx adbe net nvda meta spot zm nflx mtch sq asan roku fvrr twlo se u snap shop cvna - Cluster: 1
# ------------
# Tweet: amazon amzn cargo airline growing slowest pace since start pandemic per bloomberg - Cluster: 0
# ------------
# Tweet: pltr better msft amzn goog ai software sale ranking little ahead giant - Cluster: 0
# ------------
# Tweet: twitch amzn banned streaming gambling site include slot roulette dice game arent licensed either u jurisdiction provide sufficient consumer protection - Cluster: 0
# ------------
# Tweet: dotcom bubble already happened dont see tsla v growth stock amp faang yoy tsla se rblx roku sq tdoc fb amzn aapl nflx googl - Cluster: 1
# ------------
# Tweet: amzn biggest three hour u prime signups ever thursday chiefschargers game - Cluster: 0
# ------------
# Tweet: various way invest style suit best dividend foundation stock pep jnj pg pfe dividend growth stock trow avgo cost hd msft growth stock nvda amzn tsla googl aapl - Cluster: 1
# ------------
# Tweet: start tsla amzn aapl would master stock put necessary screen time youre learning dont make harder need - Cluster: 0
# ------------
# Tweet: news stablecoin legislation twitch amzn ban crypto gambling cv wmt opioid settlement bynd coo suspended spanberger digital disclosure gps cut htz x gm nvda next gen gpus gdpnow fine future - Cluster: 1
# ------------
# Tweet: amzn key stock still holding support bear flagto confirm immediate downside need breakdown - Cluster: 0
# ------------
# Tweet: amzn managed close right support candleit matter time imoan equal length target previous drop would put sometime next year - Cluster: 0
# ------------
# Tweet: amzn june low googl hit new ytd low today google also year date amazon seems odd considering amzn consensus eps collapsed zero year would rather - Cluster: 0
# ------------
# Tweet: largest stock performed far apple aapl microsoft msft google googl amazon amzn tesla tsla berkshire brkb unitedhealth unh jnj tsm visa v facebook meta exxon xom - Cluster: 1
# ------------
# Tweet: hit like share free play tomorrow spy qqq aapl amzn meta tsla nvda amd sq se googl etsy baba twlo - Cluster: 1
# ------------
# Tweet: amazon routinely hired dangerous trucking company wsj analysis find wsj amzn - Cluster: 0
# ------------
# Tweet: bought nvda goog amzn longer term - Cluster: 0
# ------------
# Tweet: would love see weekly candle close support amzn look pretty good continuation downward breaking bear flag - Cluster: 0
# ------------
# Tweet: yeartodate performance fb amzn aapl nflx googl msft tsla f pypl faang stock aside aapl bear market territory fact spx isnt miracle - Cluster: 1
# ------------
# Tweet: cost growing faster aapl goog meta amzn msft growing faster without leverage without dilution also none company sell hot dog drink - Cluster: 0
# ------------
# Tweet: amazon amzn stock surged announced four new version fire tablet starting amazon amzn technology stock investing stockmarket - Cluster: 0
# ------------
# Tweet: fdx isnt weakening global demand shipping theyre losing market share amzn dont want come say theyre trying buy time probably little late people know probably got long time ago stock done - Cluster: 1
# ------------
# Tweet: jeff bezos office amzn - Cluster: 0
# ------------
# Tweet: crossed k year date trading profit today made k day trading amzn post full breakdown later - Cluster: 0
# ------------
# Tweet: ai software sale company pltr b msft b ibm b amzn aws b googl b ai software - Cluster: 0
# ------------
# Tweet: greatest wealth created bear market opportunity buy company discount buy company best sector amazon amzn apple aapl home depot hd chipotle cmg mcdonalds mcd microsoft msft waste management wm - Cluster: 0
# ------------
# Tweet: return twtr aapl tsla msft goog amzn gme crm team snow adbe mrna amd pypl etsy nvda meta zm spot nflx sq snap shop - Cluster: 1
# ------------
# Tweet: since adopted bitcoin standard btc mstr goog aapl orcl msft sampp ibm nasdaq gold bond crm amzn silver meta sap nflx - Cluster: 1
# ------------
# Tweet: use make day trading tsla video must watch learn replicate watch video spx spy shop nvda amzn nflx roku tsla nio xpev gme amc bynd qcom abnb mrna rblx upst - Cluster: 1
# ------------
# Tweet: posted option flow data spy qqq iwm data shared tomorrow give following thank amzn aapl nflx googl baba meta sq se ttd v twlo etsy - Cluster: 1
# ------------
# Tweet: yeartodate performance fb aapl amzn nflx googl tsla msft dis nvda baba pypl imagine damage housing price crash next bubble officially bursting - Cluster: 1
# ------------
# Tweet: warren buffett th richest american worth billion recommends investing sampp index fund sampp made stock apple aapl microsoft msft google goog googl amazon amzn tesla tsla let discus - Cluster: 1
# ------------
# Tweet: tsla trade idea sept c closed let see tsla bottom near set bounce week put work aapl arkk amd amzn ba meta msft nflx nio es_f nvda qqq mdb spx spy tgt tsla zm - Cluster: 1
# ------------
# Tweet: option trading watchlist amzn c gt amd c gt meta p lt market remain weak room downside short technical bounce possible name exploit opportunity flow via unusual whale optionstrading - Cluster: 1
# ------------
# Tweet: amazon amzn hold midoctober sale capture holiday spending per reuters - Cluster: 0
# ------------
# Tweet: inflation reduction act impose minimum tax large corporation brkb amzn f ebay mrna nvda set hit hardest according unc tax center source - Cluster: 1
# ------------
# Tweet: option trading watchlist amzn scratch amd c gt meta p lt conservative monday market take direction well see volatility strategize exit always mitigate risk stop flow unusual whale stock see thread - Cluster: 1
# ------------
# Tweet: stock plan buy hold next year aapl msft goog amzn v holding - Cluster: 0
# ------------
# Tweet: many name held spx far le june yet spx june th aapl amzn sampp aapl amzn sampp name turn lower real sell begin - Cluster: 1
# ------------
# Tweet: option trading watchlist amzn p lt narrow list one name radar market weak range bound absent catalyst thurs flow via unusual whale revisit optionstrading stock - Cluster: 1
# ------------
# Tweet: largest public company aapl msft amzn tsla brka unh v jnj trade lower earnings yield real cash yield yr treasury today stand - Cluster: 1
# ------------
# Tweet: would support view still lot capitalmoney trying hide old mega cap tech leader aaplamznodds see downside say cop raid brothel even piano player get arrested - Cluster: 1
# ------------
# Tweet: key event tomorrow amzn - Cluster: 0
# ------------
# Tweet: fact amzn aapl tsla havent made week low broader index scare shit bull - Cluster: 0
# ------------
# Tweet: free option idea scale profit spy cgt pltinsane ob amd cgt plt msft cgt plt amzn cgt plt use ibkr fully automate order see bonus - Cluster: 1
# ------------
# Tweet: top tech stock highest share buyback past quarter aapl googl msft meta chtr nvda wmt amzn klac v csco - Cluster: 0
# ------------
# Tweet: good morning trader thanks looking stickynote pls retweet aapl slow production good pre mkt low amzn consumer weak stock fade pop amd watching low could hold lyft hiring freeze bad sign - Cluster: 1
# ------------
# Tweet: best sale right youll look back price long wish bought aapl amzn blk dis hd jnj jpm ko msft trow v else - Cluster: 0
# ------------
# Tweet: amazon amzn announced kindle scribe first kindle write - Cluster: 0
# ------------
# Tweet: amazon amzn link astro robot ring virtual security guard - Cluster: 0
# ------------
# Tweet: amazon amzn unveils device track breathe sleeping - Cluster: 0
# ------------
# Tweet: found little green today amzn ttd nnox crwd aty sq mgni shop se meta zi abnb hope got piece sending prayer friend florida - Cluster: 1
# ------------
# Tweet: amazon amzn encouraging customerservice worker u call center work home signaling preference remote work certain role would help save money real estate per bloomberg - Cluster: 0
# ------------
# Tweet: amazon raising hourly wage warehouse shipping worker amzn - Cluster: 0
# ------------
# Tweet: option trading watchlist amzn p lt twtr bearish job report impactful significant change monitoring usd strength yield well review flow via unusual whale optionstrading stock - Cluster: 1
# ------------
# Tweet: news boe buy bond save pension mortgage rate advertiser leave twtr politician stock ban bill amzn new kindle ken griffin u recession b ulkraine eu cap ru oil nordstream sabotage future - Cluster: 1
# ------------
# Tweet: stock think entering intriguing level add several im already overweight amzn goog axon celh z aapl hd ddog - Cluster: 0
# ------------
# Tweet: amazon loan small business next year bloomberg amzn - Cluster: 0
# ------------
# Tweet: wage inflation profit margin amzn - Cluster: 0
# ------------
# Tweet: top qqq holding credit rating aapl aaa msft aaa amzn tsla ba goog aa googl aa meta nvda pep cost aa coming month investor learn credit rating important - Cluster: 1
# ------------
# Tweet: druckenmiller owned cvna year munger bought baba margin aswath dean valuation damodoran loved amzn meta year one safe investing loss wary anyone always right side every trade long list bird app - Cluster: 1
# ------------
# Tweet: today drop spx perfect example happens aapl amzn turn lower name held market year name finally dropping beginning see damage healthy market driven name - Cluster: 0
# ------------
# Tweet: nio im money doesnt mean bad investment whole market everything suck right year im confident pay long best aapl amzn tsla googl nio - Cluster: 0
# ------------
# Tweet: group lawmaker led sen elizabeth warren dmass asking federal trade commission reject amazon amzn proposed acquisition irobot per letter shared first axios - Cluster: 1
# ------------

# %%
# Create a list of strings with formatted labels
formatted_labels = ['Cluster ' + str(label) for label in labels]
# Convert the list to a pandas Series
cluster_series = pd.Series(formatted_labels)
stock_tweets['Cluster'] = cluster_series

# %%
# Group by 'Cluster' and 'Label' and count occurrences
cluster_label_distribution = stock_tweets.groupby(['Stock Name', 'Cluster']).size().unstack(fill_value=0)
# Display the distribution
print(cluster_label_distribution)
# Out:
# Cluster     Cluster 0  Cluster 1
# Stock Name
# AAPL             3386       1670
# MSFT             2608       1481

# %% [markdown]
# From the above cluster label distribution, we conclude that AAPL is Cluster 0 and MSFT is Cluster 1. The accuracy evaluates to be around 53.23%.

# %% [markdown]
# ### Q2 (7 marks) Time Series Forecasting!

# %%
print(len(results))
# Out:
# 9145

# %%
def process_tweet_scores(data):
    scores = []
    for item in data:
        tweet, sentiment = item
        label = sentiment[0]['label']
        score = sentiment[0]['score']
        
        # Conditionally adjust the score based on the label
        if label == 'LABEL_0':
            score = -score  # Negative of the score
        elif label == 'LABEL_1':
            score = 0  # Score as zero
        elif label == 'LABEL_2':
            score = score  # Positive of the score
        else:
            score = 0  # Default case, unlikely to be used unless new labels are introduced

        scores.append(score)

    return pd.Series(scores)

score_series = process_tweet_scores(results)
stock_tweets['Sentiment_Score'] = score_series

# %%
stock_tweets.to_csv("stock_tweets.csv")

# %%
# Convert 'Date' from timestamp to date only
stock_tweets['Date'] = pd.to_datetime(stock_tweets['Date']).dt.date

# Group by 'Date' and 'Stock Name' and calculate the median of the 'Sentiment_Score'
daily_median_sentiment = stock_tweets.groupby(['Date', 'Stock Name'])['Sentiment_Score'].median().reset_index()

# Generate a date range covering all dates in the dataset
date_range = pd.date_range(start=min(stock_tweets['Date']), end=max(stock_tweets['Date']))

# Assume the stocks are AAPL and MSFT; adjust as necessary
symbols = stock_tweets['Stock Name'].unique()

# Create a DataFrame with all combinations of Date and Stock Name
all_dates_symbols = pd.MultiIndex.from_product([date_range.date, symbols], names=['Date', 'Stock Name'])
all_dates_symbols_df = pd.DataFrame(index=all_dates_symbols).reset_index()

# Merge the all-date-symbol DataFrame with the median sentiments
complete_sentiment = all_dates_symbols_df.merge(daily_median_sentiment, on=['Date', 'Stock Name'], how='left')

# Fill NaN values in 'Sentiment_Score' with 0, as these represent days with no tweets
complete_sentiment['Sentiment_Score'].fillna(0, inplace=True)

# %%
# Count the number of zero values in the 'Sentiment_Score' column
number_of_zeros = (complete_sentiment['Sentiment_Score'] == 0).sum()

# Print the number of zero values
print(f"Number of zero values in 'Sentiment_Score': {number_of_zeros}")

print(complete_sentiment)
# Out:
# Number of zero values in 'Sentiment_Score': 702
#            Date Stock Name  Sentiment_Score
# 0    2021-09-30       AAPL              0.0
# 1    2021-09-30       MSFT              0.0
# 2    2021-10-01       AAPL              0.0
# 3    2021-10-01       MSFT              0.0
# 4    2021-10-02       AAPL              0.0
# ..          ...        ...              ...
# 725  2022-09-27       MSFT              0.0
# 726  2022-09-28       AAPL              0.0
# 727  2022-09-28       MSFT              0.0
# 728  2022-09-29       AAPL              0.0
# 729  2022-09-29       MSFT              0.0
#
# [730 rows x 3 columns]

# %%
complete_sentiment['Sentiment_Score'].describe()
# Out:
# count    730.000000
# mean       0.012579
# std        0.084342
# min       -0.567745
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.821257
# Name: Sentiment_Score, dtype: float64

# %%
# Computation of returns
stock_data = stock_data.dropna(how='all')
print(stock_data.shape)
# Out:
# (504, 8)

# %%
# Returns calculation
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data.sort_values(by=['Stock Name', 'Date'], inplace=True)
stock_data['Daily Returns'] = stock_data.groupby('Stock Name')['Adj Close'].pct_change()

# %%
#Y1 calculation
# Filter out AAPL and MSFT into separate DataFrames
aapl_df = stock_data[stock_data['Stock Name'] == 'AAPL']
msft_df = stock_data[stock_data['Stock Name'] == 'MSFT']
# Ensure that both DataFrames are sorted by date (if not already)
aapl_df = aapl_df.sort_values(by='Date')
msft_df = msft_df.sort_values(by='Date')
# Add a new column 'AAPL_ge_MSFT' where 1 means AAPL's return >= MSFT's return, 0 otherwise
comparison_df = pd.merge(aapl_df, msft_df, on='Date', suffixes=('_AAPL', '_MSFT'))
comparison_df['AAPL_ge_MSFT'] = (comparison_df['Daily Returns_AAPL'] >= comparison_df['Daily Returns_MSFT']).astype(int)
stock_data['Y1'] = comparison_df['AAPL_ge_MSFT'].append(comparison_df['AAPL_ge_MSFT'],  ignore_index=True)
# Out:
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_27052/2111167754.py:11: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock_data['Y1'] = comparison_df['AAPL_ge_MSFT'].append(comparison_df['AAPL_ge_MSFT'],  ignore_index=True)

# %%
#Y2 Weekly Forward Volatility data
stock_data['Date'] = pd.to_datetime(stock_data['Date'])  # Ensuring 'Date' is in datetime format
stock_data.sort_values(by=['Stock Name', 'Date'], inplace=True)

# Define a function to apply the forward-looking rolling standard deviation
def calculate_forward_weekly_volatility(group):
    # Calculate rolling std dev of the next 5 days, including the current day
    # Shift the results back by 4 places so the volatility corresponds to the current day
    group['Forward Weekly Volatility'] = group['Daily Returns'].rolling(window=5).std().shift(-4)
    return group

# Apply the function separately for each stock
stock_data = stock_data.groupby('Stock Name').apply(calculate_forward_weekly_volatility)
# Out:
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_27052/2139574865.py:13: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   stock_data = stock_data.groupby('Stock Name').apply(calculate_forward_weekly_volatility)

# %%
# X1 calculating the Backward Volatility data
def calculate_backward_weekly_volatility(group):
    # Calculate the rolling standard deviation for a window of 5 days
    group['Backward Weekly Volatility'] = group['Daily Returns'].rolling(window=5).std()
    return group

stock_data = stock_data.groupby('Stock Name').apply(calculate_backward_weekly_volatility)
# Out:
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_27052/861739827.py:7: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   stock_data = stock_data.groupby('Stock Name').apply(calculate_backward_weekly_volatility)

# %%
# Adding lagged stock winner data
for i in range(1, 6):
    stock_data[f'Y1_t-{i}'] = stock_data.groupby('Stock Name')['Y1'].shift(i)

# %%
# Adding the Sentiment_Score to the stock_data dataframe
# Convert 'Date' to datetime in both DataFrames, if not already done
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
complete_sentiment['Date'] = pd.to_datetime(complete_sentiment['Date'])

stock_data = stock_data.merge(complete_sentiment[['Date', 'Stock Name', 'Sentiment_Score']],
                              on=['Date', 'Stock Name'],
                              how='left')

# %%
# Adding lagged Sentiment Score data
for i in range(1, 6):
    stock_data[f'Sentiment_Score_Lag_{i}'] = stock_data.groupby('Stock Name')['Sentiment_Score'].shift(i)

# %%
# Adding the Apple_wins in 5 days
stock_data['Apple_Wins_5'] = stock_data[['Y1_t-1', 'Y1_t-2', 'Y1_t-3', 'Y1_t-4', 'Y1_t-5']].fillna(0).sum(axis=1)

# %%
stock_data.to_csv("stock_data_my_OP.csv")

# %% [markdown]
# ### Modeling

# %%
# Convert 'Date' to datetime if not already done
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
# Find the maximum date in the dataset
max_date = stock_data['Date'].max()
# Calculate the date two months before the maximum date
split_date = max_date - pd.DateOffset(months=2)

# Split the data into training and validation sets
train_data = stock_data[stock_data['Date'] <= split_date]
validation_data = stock_data[stock_data['Date'] > split_date]

# Encoding the 'Stock Name' column
train_data['Stock_Name_Encoded'] = np.where(train_data['Stock Name'] == 'AAPL', 1, 0)
validation_data['Stock_Name_Encoded'] = np.where(validation_data['Stock Name'] == 'AAPL', 1, 0)
# Out:
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_27052/3577766531.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Stock_Name_Encoded'] = np.where(train_data['Stock Name'] == 'AAPL', 1, 0)
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_27052/3577766531.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data['Stock_Name_Encoded'] = np.where(validation_data['Stock Name'] == 'AAPL', 1, 0)

# %%
# Print the details of the splits
print(f"Training data range: {train_data['Date'].min()} to {train_data['Date'].max()}")
print(f"Validation data range: {validation_data['Date'].min()} to {validation_data['Date'].max()}")
print(f"Training set size: {train_data.shape[0]} rows")
print(f"Validation set size: {validation_data.shape[0]} rows")
# Out:
# Training data range: 2021-09-30 00:00:00 to 2022-07-29 00:00:00
# Validation data range: 2022-08-01 00:00:00 to 2022-09-29 00:00:00
# Training set size: 418 rows
# Validation set size: 86 rows

# %% [markdown]
# ### LSTM - Classification

# %%
# Features and target
features = ['Stock_Name_Encoded','Backward Weekly Volatility', 'Y1_t-1', 'Y1_t-2', 'Y1_t-3', 'Y1_t-4', 'Y1_t-5', 'Sentiment_Score_Lag_1', 'Sentiment_Score_Lag_2', 
            'Sentiment_Score_Lag_3', 'Sentiment_Score_Lag_4', 'Sentiment_Score_Lag_5', 'Apple_Wins_5']
target = 'Y1'

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_data[features])
X_val_scaled = scaler.transform(validation_data[features])

# Targets
y_train = train_data[target].values
y_val = validation_data[target].values

# Reshape for LSTM [samples, time steps, features]
X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
X_val_scaled = X_val_scaled.reshape((X_val_scaled.shape[0], 1, X_val_scaled.shape[1]))

# %%
# Revised model architecture
model = Sequential([
    Bidirectional(LSTM(50, return_sequences=True), input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])),
    Dropout(0.3),
    LSTM(100),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /Users/balubabu/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Evaluate the model on the validation set
performance = model.evaluate(X_val_scaled, y_val, verbose=1)
print(f'Validation Accuracy: {performance[1]}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5585 - loss: 0.6931
# Validation Accuracy: 0.5232558250427246

# %% [markdown]
# ### LGBM - Classification

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_data[features])
X_val_scaled = scaler.transform(validation_data[features])

# Prepare the target values
y_train = train_data[target].values
y_val = validation_data[target].values

# Create LightGBM datasets
train_set = lgb.Dataset(X_train_scaled, label=y_train)
valid_set = lgb.Dataset(X_val_scaled, label=y_val, reference=train_set)

# %%
# Set the parameters for the model
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

num_boost_round = 1000
lgbm_model = lgb.train(
    params,
    train_set,
    num_boost_round=num_boost_round,
    valid_sets=[valid_set],
    callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.log_evaluation(period=10)]
)

# Make predictions
y_pred = lgbm_model.predict(X_val_scaled, num_iteration=lgbm_model.best_iteration)
# Convert probabilities to binary output
y_pred_binary = np.where(y_pred > 0.5, 1, 0)

# Calculate accuracy
accuracy = accuracy_score(y_val, y_pred_binary)
print("------------------------------")
print(f'Validation Accuracy: {accuracy}')
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.691371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.677172
# ------------------------------
# Validation Accuracy: 0.627906976744186

# %% [markdown]
# ### LightGBM for volatility

# %%
# Standardizing the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_data[features])
X_val_scaled = scaler.transform(validation_data[features])

y_train = train_data[target]
y_val = validation_data[target]

# Setting up LightGBM dataset for regression
train_set = lgb.Dataset(X_train_scaled, label=y_train)
val_set = lgb.Dataset(X_val_scaled, label=y_val, reference=train_set)

# Setting parameters for regression
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'l2',  # Use Mean Squared Error as the loss ('l2' in LightGBM)
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

# %%
# Train the regression model
num_boost_round = 1000
model = lgb.train(
    params,
    train_set,
    num_boost_round=num_boost_round,
    valid_sets=[val_set],
    callbacks=[lgb.early_stopping(stopping_rounds=50), lgb.log_evaluation(period=10)]
)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 50 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 0.249695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 0.258531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 0.266395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 0.26903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 0.278189
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.242025

# %%
# Predictions on the validation set
y_pred = model.predict(X_val_scaled, num_iteration=model.best_iteration)

# Evaluate the model using R-squared metric
r_squared = r2_score(y_val, y_pred)
print(f'R-squared for the validation set: {r_squared}')
# Out:
# R-squared for the validation set: -0.03589090316559451
